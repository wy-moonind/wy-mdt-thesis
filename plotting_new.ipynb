# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import sys
import seaborn as sn

parameters = {'axes.labelsize': 15,
        'axes.titlesize': 5,
        'figure.titlesize': 5,
        'xtick.labelsize': 10,
        'ytick.labelsize': 10,
        'savefig.dpi': 300,
        'figure.dpi': 300,
        'lines.linewidth': 1.5,
        'axes.linewidth': 0.4,
        'xtick.major.width': 0.4,
        'ytick.major.width': 0.4,
        'xtick.major.pad': 1,
        'ytick.major.pad': 1}
plt.rcParams.update(parameters)

def norm(x):
    xmax = max(x)
    xmin = min(x)
    for i in range(len(x)):
        x[i] = (x[i] - xmin)/(xmax - xmin)
    return x

# %%
order = [3, 5, 7, 9, 11, 13, 15]
layer = [1, 2, 3, 4, 5]
# multi_layer = [[0.65614,0.66702,0.6908,0.71,0.75738,0.77134,0.78094], 
#               [0.6567,0.652666667,0.714666667,0.7468,0.7458,0.748833333,0.7297], 
#               [0.640733333,0.674366667,0.718166667,0.7267,0.7766,0.7749,0.782233333], 
#               [0.622433333,0.658333333,0.687266667,0.7409,0.768466667,0.7785,0.784166667],
#               [0.654466667,0.659166667,0.734,0.722533333,0.753233333,0.779933333,0.783933333]]
multi_layer = [[0.92694,0.93024,0.92966,0.92714,0.9281,0.93026,0.93172], 
              [0.930233333,0.927333333,0.9295,0.927433333,0.9303,0.930866667,0.926966667], 
              [0.927766667,0.9266,0.931,0.9288,0.9228,0.927633333,0.9315], 
              [0.923133333,0.929366667,0.916366667,0.9193,0.921366667,0.9274,0.930466667],
              [0.9243,0.915333333,0.9198,0.920566667,0.9242,0.925166667,0.935033333]]
plt.figure(figsize=(6,4))
plt.plot(order, multi_layer[0])
plt.plot(order, multi_layer[1])
plt.plot(order, multi_layer[2])
plt.plot(order, multi_layer[3])
plt.plot(order, multi_layer[4])

plt.legend(['Layer 1', 'Layer 2', 'Layer 3', 'Layer 4', 'Layer 5'])

plt.figure(figsize=(6,4))
plt.plot(layer, [np.mean(multi_layer[0][3:]),np.mean(multi_layer[1][3:]),np.mean(multi_layer[2][3:]),np.mean(multi_layer[3][3:]),np.mean(multi_layer[4][3:])])


plt.show()

# %%
label = [3, 5, 7, 9, 11, 13, 15]

# outer07 tanh
r2_3_tanh = [0.0177,0.0171,0.0154,0.0167,0.0175]
r2_5_tanh = [0.0218,0.2087,0.0197,0.0146,0.0269]
r2_7_tanh = [0.0334,0.0285,0.0251,0.0256,0.0223]
r2_9_tanh = [0.0634,0.0397,0.0368,0.0281,0.0242]
r2_11_tanh = [0.2349,0.0545,0.2383,0.2249,0.2463]
r2_13_tanh = [0.0378,0.2112,0.246,0.0303,0.0461]
r2_15_tanh = [0.2487,0.2488,0.0325,0.2458,0.05]
# outer07 relu
r2_3_relu = [0.0174,0.03,0.0213,0.0158,0.0215]
r2_5_relu = [0.0214,0.0181,0.0313,0.0253,0.0571]
r2_7_relu = [0.0297,-0.1518,0.0326,0.0323,0.0254]
r2_9_relu = [0.0293,0.2468,0.0313,0.2328,0.2204]
r2_11_relu = [0.0356,0.248,0.2433,0.0819,-0.1417]
r2_13_relu = [-0.1339,0.2398,0.0488,0.0349,0.2415]
r2_15_relu = [-0.1482,0.2468,0.0346,0.2365,0.2414]
# outer07 softplus
r2_3_softplus = [0.0041,0.0089,0.0143,0.0112,0.0099]
r2_5_softplus = [0.019,0.0169,0.0198,0.02,0.0126]
r2_7_softplus = [0.2154,0.0506,0.0246,0.2186,0.0245]
r2_9_softplus = [0.0314,0.0554,0.0288,0.0293,0.2096]
r2_11_softplus = [0.2118,0.0315,0.0313,0.0316,0.2248]
r2_13_softplus = [0.2253,0.0429,0.0418,0.2318,0.229]
r2_15_softplus = [0.0359,0.2345,0.0328,0.2272,0.0375]
# plt.figure(figsize=(6,4))
# plt.boxplot([r2_3_tanh, r2_5_tanh, r2_7_tanh, r2_9_tanh, r2_11_tanh, r2_13_tanh, r2_15_tanh], labels=label, showmeans=True)
# plt.ylabel("R2 score")
# plt.xlabel("Order of model")
# plt.savefig("../figs/outer07_box_tanh", dpi=300, bbox_inches='tight')
# plt.figure(figsize=(6,4))
# plt.boxplot([r2_3_relu, r2_5_relu, r2_7_relu, r2_9_relu, r2_11_relu, r2_13_relu, r2_15_relu], labels=label, showmeans=True)
# plt.ylabel("R2 score")
# plt.xlabel("Order of model")
# plt.savefig("../figs/outer07_box_relu", dpi=300, bbox_inches='tight')
# plt.figure(figsize=(6,4))
# plt.boxplot([r2_3_softplus, r2_5_softplus, r2_7_softplus, r2_9_softplus, r2_11_softplus, r2_13_softplus, r2_15_softplus], labels=label, showmeans=True)
# plt.ylabel("R2 score")
# plt.xlabel("Order of model")
# plt.savefig("../figs/outer07_box_softplus", dpi=300, bbox_inches='tight')

# # outer21 tanh
# r2_3_tanh = [-0.0239,-0.022,-0.0149,-0.0227,-0.0163]
# r2_5_tanh = [-0.0152,-0.027,-0.0177,0.0005,-0.0341]
# r2_7_tanh = [0.0114,-0.0295,0.0481,-0.0011,-0.0104]
# r2_9_tanh = [0.0247,0.0085,0.009,0.0862,-0.0057]
# r2_11_tanh = [-0.0031,-0.0025,0.0134,0.0184,0.0029]
# r2_13_tanh = [0.0897,-0.0101,0.0026,0.0065,0.0797]
# r2_15_tanh = [0.0052,0.1132,0.0008,0.1336,0.0207]
# # outer21 relu
# r2_3_relu = [-0.0227,-0.0242,-0.0196,-0.0219,-0.0336]
# r2_5_relu = [-0.0178,-0.0086,-0.0128,-0.0101,-0.0063]
# r2_7_relu = [-0.0125,-0.0252,-0.0086,-0.0151,-0.0064]
# r2_9_relu = [0.0071,0.0055,-0.0091,-0.0061,0.0076]
# r2_11_relu = [0.0228,-0.0022,0.1448,0.0144,0.0101]
# r2_13_relu = [0.0111,0.0567,0.0598,0.0016,0.1617]
# r2_15_relu = [0.0107,-0.2003,0.0217,0.0169,-0.4106]
# # outer21 softplus
# r2_3_softplus = [-0.0517,-0.047,-0.0432,-0.0443,-0.0439]
# r2_5_softplus = [-0.0287,-0.0007,0.0056,-0.0229,-0.0087]
# r2_7_softplus = [-0.0171,-0.0213,-0.0171,-0.019,-0.0052]
# r2_9_softplus = [0.0043,-0.0057,-0.0026,0.0984,-0.0095]
# r2_11_softplus = [-0.0085,0.106,-0.0014,-0.0087,0.1411]
# r2_13_softplus = [0.1044,0.0035,0.0654,-0.0048,0.031]
# r2_15_softplus = [0.1005,0.1166,0.0125,0.1275,0.1063]
# plt.figure(figsize=(6,4))
# plt.boxplot([r2_3_tanh, r2_5_tanh, r2_7_tanh, r2_9_tanh, r2_11_tanh, r2_13_tanh, r2_15_tanh], labels=label, showmeans=True)
# plt.ylabel("R2 score")
# plt.xlabel("Order of model")
# plt.savefig("../figs/outer21_box_tanh", dpi=300, bbox_inches='tight')
# plt.figure(figsize=(6,4))
# plt.boxplot([r2_3_relu, r2_5_relu, r2_7_relu, r2_9_relu, r2_11_relu, r2_13_relu, r2_15_relu], labels=label, showmeans=True)
# plt.ylabel("R2 score")
# plt.xlabel("Order of model")
# plt.savefig("../figs/outer21_box_relu", dpi=300, bbox_inches='tight')
# plt.figure(figsize=(6,4))
# plt.boxplot([r2_3_softplus, r2_5_softplus, r2_7_softplus, r2_9_softplus, r2_11_softplus, r2_13_softplus, r2_15_softplus], labels=label, showmeans=True)
# plt.ylabel("R2 score")
# plt.xlabel("Order of model")
# plt.savefig("../figs/outer21_box_softplus", dpi=300, bbox_inches='tight')

# # outer07 woobs
r2_3 = [0.0186,0.032,0.0166,0.023,0.018]
r2_5 = [0.025,0.025,0.028,0.025,0.026]
r2_7 = [0.032,0.028,0.031,0.028,0.029]
r2_9 = [0.034,0.241,0.033,0.028,0.031]
r2_11 = [0.0797,0.2474,0.2297,0.2371,0.2464]
r2_13 = [0.2414,0.2375,0.0366,0.2365,0.0415]
r2_15 = [0.2334,0.2488,0.254,0.2364,0.2147]
# outer21 woobs
# r2_3 = [-0.0082,-0.0271,-0.0084,-0.0247,-0.013]
# r2_5 = [0.0014,-0.0042,-0.0081,-0.0112,0.0052]
# r2_7 = [0.0287,0.0062,0.0106,-0.0092,0.1047]
# r2_9 = [0.0959,0.014,0.0042,0.0132,-0.003]
# r2_11 = [0.1112,0.0245,0.014,0.1431,0.0581]
# r2_13 = [0.1016,0.1606,0.1412,0.1705,0.0349]
# r2_15 = [0.1062,0.1421,0.153,0.0921,0.1228]

outer_woobs_mean = [np.mean(r2_3), np.mean(r2_5), np.mean(r2_7), np.mean(r2_9), np.mean(r2_11), np.mean(r2_13), np.mean(r2_15)]
outer_tanh_mean = [np.mean(r2_3_tanh), np.mean(r2_5_tanh), np.mean(r2_7_tanh), np.mean(r2_9_tanh), np.mean(r2_11_tanh), np.mean(r2_13_tanh), np.mean(r2_15_tanh)]
outer_relu_mean = [np.mean(r2_3_relu), np.mean(r2_5_relu), np.mean(r2_7_relu), np.mean(r2_9_relu), np.mean(r2_11_relu), np.mean(r2_13_relu), np.mean(r2_15_relu)]
outer_softplus_mean = [np.mean(r2_3_softplus), np.mean(r2_5_softplus), np.mean(r2_7_softplus), np.mean(r2_9_softplus), np.mean(r2_11_softplus), np.mean(r2_13_softplus), np.mean(r2_15_softplus)]

plt.figure(figsize=(6,4))
plt.plot(outer_woobs_mean)
plt.plot(outer_tanh_mean)
plt.plot(outer_relu_mean)
plt.plot(outer_softplus_mean)
plt.grid(axis='y')
plt.legend(['Baseline', 'Tanh activation', 'ReLu activation', 'Softplus activation'])
plt.ylabel('Average R2 score')
plt.xlabel('Order of model')
plt.savefig("../figs/outer07_compare_active", dpi=300, bbox_inches='tight')

# %%
label = [3, 5, 7, 9, 11, 13, 15]

# outer07 woobs
r2_3 = [0.0186,0.032,0.0166,0.023,0.018]
r2_5 = [0.025,0.025,0.028,0.025,0.026]
r2_7 = [0.032,0.028,0.031,0.028,0.029]
r2_9 = [0.034,0.241,0.033,0.028,0.031]
r2_11 = [0.0797,0.2474,0.2297,0.2371,0.2464]
r2_13 = [0.2414,0.2375,0.0366,0.2365,0.0415]
r2_15 = [0.2334,0.2488,0.254,0.2364,0.2147]
# outer21 woobs
# r2_3 = [-0.0082,-0.0271,-0.0084,-0.0247,-0.013]
# r2_5 = [0.0014,-0.0042,-0.0081,-0.0112,0.0052]
# r2_7 = [0.0287,0.0062,0.0106,-0.0092,0.1047]
# r2_9 = [0.0959,0.014,0.0042,0.0132,-0.003]
# r2_11 = [0.1112,0.0245,0.014,0.1431,0.0581]
# r2_13 = [0.1016,0.1606,0.1412,0.1705,0.0349]
# r2_15 = [0.1062,0.1421,0.153,0.0921,0.1228]

plt.figure(figsize=(6,4))
plt.boxplot([r2_3, r2_5, r2_7, r2_9, r2_11, r2_13, r2_15], labels=label, showmeans=True)
plt.ylabel("R2 score")
plt.xlabel("Order of model")
plt.savefig("../figs/outer07_box_woobs", dpi=300, bbox_inches='tight')
