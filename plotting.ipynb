# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import sys

# %%
order = [3, 5, 7, 9, 11, 13, 15]
# linear
sig_l_outer21 = [[0.243,0.24,0.238,0.23,0.188,0.205,0.202], 
                [0.23,0.228,0.227,0.216,0.171,0.186,0.189], 
                [0.457,0.467,0.47,0.521,0.701,0.645,0.635]]
tri_l_outer21 = [[0.254,0.251,0.249,0.25,0.226,0.215,0.215], 
                [0.235,0.235,0.234,0.229,0.213,0.197,0.195], 
                [0.433,0.433,0.443,0.466,0.534,0.605,0.611]]
tri_spec_l_outer21 = [[0.232,0.226,0.207,0.199,0.191,0.18,0.175], 
                [0.214,0.213,0.189,0.176,0.173,0.164,0.16], 
                [0.532,0.534,0.634,0.68,0.694,0.722,0.739]]

sig_l_inner07 = [[0.21,0.205,0.166,0.155,0.155,0.163,0.147], 
                [0.205,0.198,0.159,0.147,0.14,0.149,0.137], 
                [0.59,0.616,0.751,0.788,0.808,0.783,0.816]]
tri_l_inner07 = [[0.225,0.225,0.185,0.169,0.174,0.164,0.16], 
                [0.218,0.219,0.176,0.162,0.163,0.15,0.147], 
                [0.538,0.534,0.698,0.741,0.74,0.78,0.789]]
tri_spec_l_inner07 = [[0.216,0.217,0.162,0.145,0.156,0.152,0.128], 
                [0.212,0.216,0.154,0.132,0.14,0.143,0.117], 
                [0.561,0.546,0.769,0.829,0.808,0.798,0.864]]
plt.figure(0)
plt.plot(order, sig_l_outer21[2])
plt.plot(order, tri_l_outer21[2])
plt.plot(order, tri_spec_l_outer21[2])

plt.legend(["Single layer", "3 layers", "3 layers(simple function)"])
plt.ylim(0.3, 0.9)
plt.grid(True)
plt.title("Validation R2 comparison(linear observer, outer21)")
plt.xlabel("Order")
plt.ylabel("R-squared")
plt.savefig('../figs/layers_compare/layer_outer21_linear', dpi=300)

plt.figure(1)
plt.plot(order, sig_l_inner07[2])
plt.plot(order, tri_l_inner07[2])
plt.plot(order, tri_spec_l_inner07[2])

plt.legend(["Single layer", "3 layers", "3 layers(simple function)"])
plt.ylim(0.4, 1)
plt.grid(True)
plt.title("Validation R2 comparison(linear observer, inner07)")
plt.xlabel("Order")
plt.ylabel("R-squared")
plt.savefig('../figs/layers_compare/layer_inner07_linear', dpi=300)

# non linear
sig_nl_outer21 = [0.52,0.579,0.618,0.649,0.724,0.712,0.756]
tri_nl_outer21 = [0.527,0.548,0.541,0.627,0.67,0.643,0.671]
tri_spec_nl_outer21 = [0.532,0.534,0.634,0.68,0.694,0.722,0.739]

sig_nl_inner07 = [0.768,0.769,0.78,0.791,0.864,0.848,0.865]
tri_nl_inner07 = [0.715,0.716,0.764,0.749,0.785,0.852,0.83]
tri_spec_nl_inner07 = [0.712,0.802,0.781,0.795,0.872,0.902,0.884]
plt.figure(2)
plt.plot(order, sig_nl_outer21)
plt.plot(order, tri_nl_outer21)
plt.plot(order, tri_spec_nl_outer21)

plt.legend(["Single layer", "3 layers", "3 layers(simple function)"])
plt.ylim(0.4, 1)
plt.grid(True)
plt.title("Validation R2 comparison(non-linear observer, outer21)")
plt.xlabel("Order")
plt.ylabel("R-squared")
plt.savefig('../figs/layers_compare/layer_outer21_nonlinear', dpi=300)

plt.figure(3)
plt.plot(order, sig_nl_inner07)
plt.plot(order, tri_nl_inner07)
plt.plot(order, tri_spec_nl_inner07)

plt.legend(["Single layer", "3 layers", "3 layers(simple function)"])
plt.ylim(0.5, 1)
plt.grid(True)
plt.title("Validation R2 comparison(non-linear observer, inner07)")
plt.xlabel("Order")
plt.ylabel("R-squared")
plt.savefig('../figs/layers_compare/layer_inner07_nonlinear', dpi=300)

# %%
# case 07 data
df = pd.read_csv('../case_21.csv', header=None, sep=',')
df = np.array(df)
print(df.shape)
train_org = df[:5, :7]
val_org = df[:5, 7:14]
r2_org = df[:5, 14:]
print(train_org)
train_org_order = np.average(train_org, axis=0) # 每列平均（不同order）
val_org_order = np.average(val_org, axis=0) # 每列平均（不同order）
r2_org_order = np.average(r2_org, axis=0) # 每列平均（不同order）
train_org_layer = np.average(train_org, axis=1) # 每行平均（不同layer）
val_org_layer = np.average(val_org, axis=1) # 每行平均（不同layer）
r2_org_layer = np.average(r2_org, axis=1) # 每行平均（不同layer）

train_tanh = df[6:11, :7]
val_tanh = df[6:11, 7:14]
r2_tanh = df[6:11, 14:]
train_tanh_order = np.average(train_tanh, axis=0) # 每列平均（不同order）
val_tanh_order = np.average(val_tanh, axis=0) # 每列平均（不同order）
r2_tanh_order = np.average(r2_tanh, axis=0) # 每列平均（不同order）
train_tanh_layer = np.average(train_tanh, axis=1) # 每行平均（不同layer）
val_tanh_layer = np.average(val_tanh, axis=1) # 每行平均（不同layer）
r2_tanh_layer = np.average(r2_tanh, axis=1) # 每行平均（不同layer）

train_relu = df[12, :7]
val_relu = df[12, 7:14]
r2_relu = df[12, 14:]

train_softplus = df[14, :7]
val_softplus = df[14, 7:14]
r2_softplus = df[14, 14:]

layer = [1, 2, 3, 4, 5]
order = [3, 5, 7, 9, 11, 13, 15]

# %%
# comparing tanh and None
plt.figure(0)
plt.plot(order, train_org_order)
plt.plot(order, train_tanh_order)
plt.grid(True)
plt.ylim(0.15, 0.3)
plt.legend(['None', 'Tanh'])
plt.title('Training loss with/without Tanh activation (different orders)')
plt.xlabel('Order')
plt.ylabel('RMSE loss')
plt.savefig('../figs/activation/multi_train_21_order', dpi=300)

plt.figure(1)
plt.plot(order, val_org_order)
plt.plot(order, val_tanh_order)
plt.grid(True)
plt.ylim(0.15, 0.3)
plt.legend(['None', 'Tanh'])
plt.title('Validation loss with/without Tanh activation (different orders)')
plt.xlabel('Order')
plt.ylabel('RMSE loss')
plt.savefig('../figs/activation/multi_val_21_order', dpi=300)

plt.figure(2)
plt.plot(order, r2_org_order)
plt.plot(order, r2_tanh_order)
plt.grid(True)
plt.ylim(0.3, 0.67)
plt.legend(['None', 'Tanh'])
plt.title('Validation r2 with/without Tanh activation (different orders)')
plt.xlabel('Order')
plt.ylabel('R2')
plt.savefig('../figs/activation/multi_r2_21_order', dpi=300)

plt.figure(3)
plt.plot(layer, train_org_layer)
plt.plot(layer, train_tanh_layer)
plt.grid(True)
plt.ylim(0.15, 0.3)
plt.legend(['None', 'Tanh'])
plt.title('Train loss with/without Tanh activation (different layers)')
plt.xlabel('Layer')
plt.ylabel('RMSE loss')
plt.savefig('../figs/activation/multi_train_21_layer', dpi=300)

plt.figure(4)
plt.plot(layer, val_org_layer)
plt.plot(layer, val_tanh_layer)
plt.grid(True)
plt.ylim(0.15, 0.3)
plt.legend(['None', 'Tanh'])
plt.title('Validation loss with/without Tanh activation (different layers)')
plt.xlabel('Layer')
plt.ylabel('RMSE loss')
plt.savefig('../figs/activation/multi_val_21_layer', dpi=300)

plt.figure(5)
plt.plot(layer, r2_org_layer)
plt.plot(layer, r2_tanh_layer)
plt.grid(True)
plt.ylim(0.3, 0.67)
plt.legend(['None', 'Tanh'])
plt.title('Validation r2 with/without Tanh activation (different layers)')
plt.xlabel('Layer')
plt.ylabel('R2')
plt.savefig('../figs/activation/multi_r2_21_layer', dpi=300)

# %%
# case 07 tanh single
plt.figure(0)
# train loss
plt.plot(order, train_org[0,:])
plt.plot(order, train_tanh[0,:])
plt.plot(order, train_relu[:])
plt.plot(order, train_softplus[:])
plt.legend(['None', 'Tanh', 'ReLU', 'Softplus'])
plt.ylim(0.1, 0.4)
plt.title('Different activation for single layer (train loss)')
plt.xlabel('Order')
plt.ylabel('RMSE loss')
plt.grid(True)
plt.savefig('../figs/activation/single_train_21', dpi=300)

plt.figure(1)
# val loss
plt.plot(order, val_org[0,:])
plt.plot(order, val_tanh[0,:])
plt.plot(order, val_relu[:])
plt.plot(order, val_softplus[:])
plt.legend(['None', 'Tanh', 'ReLU', 'Softplus'])
plt.ylim(0.1, 0.4)
plt.title('Different activation for single layer (validation loss)')
plt.xlabel('Order')
plt.ylabel('RMSE loss')
plt.grid(True)
plt.savefig('../figs/activation/single_val_21', dpi=300)

plt.figure(2)
# val r2
plt.plot(order, r2_org[0,:])
plt.plot(order, r2_tanh[0,:])
plt.plot(order, r2_relu[:])
plt.plot(order, r2_softplus[:])
plt.legend(['None', 'Tanh', 'ReLU', 'Softplus'])
plt.ylim(0, 0.7)
plt.title('Different activation for single layer (validation R2)')
plt.xlabel('Order')
plt.ylabel('R2 value')
plt.grid(True)
plt.savefig('../figs/activation/single_r2_21', dpi=300)

# %%
order = [3, 5, 7, 9, 11, 13, 15]
# outer21
train_loss_obs = [[0.244,0.242,0.243,0.243,0.21,0.21,0.214], [0.254,0.251,0.249,0.25,0.226,0.215,0.215]]
val_loss_obs = [[0.232,0.231,0.231,0.232,0.197,0.194,0.201], [0.235,0.235,0.234,0.229,0.213,0.197,0.195]]
val_r2_obs = [[0.447,0.451,0.451,0.449,0.604,0.611,0.585], [0.433,0.433,0.443,0.466,0.534,0.605,0.611]]

train_woobs = [[0.335,0.331,0.328,0.323,0.328,0.302,0.305], [0.339,0.33,0.33,0.33,0.33,0.305,0.272]]
val_woobs = [[0.325,0.32,0.319,0.31,0.319,0.277,0.277], [0.328,0.316,0.32,0.324,0.318,0.277,0.272]]
val_r2_woobs = [[-0.07,-0.048,-0.04,0.012,-0.042,0.206,0.215], [-0.105,-0.02,-0.05,-0.087,-0.036,0.209,0.241]]

train_loss_nl = [[0.244,0.239,0.206,0.203,0.204,0.191,0.192], [0.251,0.243,0.228,0.208,0.21,0.206,0.208]]
val_loss_nl = [[0.226,0.221,0.182,0.18,0.184,0.174,0.171], [0.229,0.224,0.201,0.19,0.186,0.191,0.182]]
val_r2_nl = [[0.475,0.499,0.661,0.668,0.653,0.69,0.7], [0.461,0.487,0.585,0.63,0.646,0.625,0.657]]

train_loss_50 = [[0.23,0.216,0.208,0.201,0.184,0.188,0.169], [0.241,0.229,0.235,0.209,0.2,0.206,0.197]]
val_loss_50 = [[0.216,0.203,0.192,0.185,0.164,0.167,0.153], [0.215,0.21,0.211,0.191,0.179,0.187,0.179]]
val_r2_50 = [[0.52,0.579,0.618,0.649,0.724,0.712,0.756], [0.527,0.548,0.541,0.627,0.67,0.643,0.671]]

train_loss_25 = [[0.244,0.239,0.243,0.208,0.194,0.189,0.188], [0.262,0.245,0.235,0.25,0.242,0.214,0.216]]
val_loss_25 = [[0.226,0.221,0.228,0.183,0.172,0.166,0.167], [0.242,0.22,0.214,0.231,0.22,0.192,0.189]]
val_r2_25 = [[0.476,0.504,0.467,0.656,0.699,0.716,0.715], [0.403,0.501,0.529,0.452,0.5,0.619,0.635]]

plt.figure(0)
plt.plot(order, train_loss_obs[0])
plt.plot(order, train_loss_nl[0])
plt.plot(order, train_loss_25[0])
plt.plot(order, train_loss_50[0])
plt.legend(["Luenberg Observer", "NLESO, trainable $\delta$", "NLESO, fixed $\delta$=0.25", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.15,0.3)
plt.grid(True)
plt.title("Different observer on single layer (training, data: outer_21)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/outer_21/single_all_train', dpi=300)

plt.figure(1)
plt.plot(order, val_loss_obs[0])
plt.plot(order, val_loss_nl[0])
plt.plot(order, val_loss_25[0])
plt.plot(order, val_loss_50[0])
plt.legend(["Luenberg Observer", "NLESO, trainable $\delta$", "NLESO, fixed $\delta$=0.25", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.15,0.3)
plt.grid(True)
plt.title("Different observer on single layer (validation, data: outer_21)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/outer_21/single_all_val', dpi=300)

plt.figure(2)
plt.plot(order, val_r2_obs[0])
plt.plot(order, val_r2_nl[0])
plt.plot(order, val_r2_25[0])
plt.plot(order, val_r2_50[0])
plt.legend(["Luenberg Observer", "NLESO, trainable $\delta$", "NLESO, fixed $\delta$=0.25", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.3,0.9)
plt.grid(True)
plt.title("Different observer on single layer (validation r2, data: outer_21)")
plt.xlabel("Order")
plt.ylabel("R2")

plt.savefig('../figs/nonlinear/outer_21/single_all_r2', dpi=300)

plt.figure(3)
plt.plot(order, train_loss_obs[1])
plt.plot(order, train_loss_nl[1])
plt.plot(order, train_loss_25[1])
plt.plot(order, train_loss_50[1])
plt.legend(["Luenberg Observer", "NLESO, trainable $\delta$", "NLESO, fixed $\delta$=0.25", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.15,0.3)
plt.grid(True)
plt.title("Different observer on triple layer (training, data: outer_21)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/outer_21/triple_all_train', dpi=300)

plt.figure(4)
plt.plot(order, val_loss_obs[1])
plt.plot(order, val_loss_nl[1])
plt.plot(order, val_loss_25[1])
plt.plot(order, val_loss_50[1])
plt.legend(["Luenberg Observer", "NLESO, trainable $\delta$", "NLESO, fixed $\delta$=0.25", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.15,0.3)
plt.grid(True)
plt.title("Different observer on triple layer (validation, data: outer_21)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/outer_21/triple_all_val', dpi=300)

plt.figure(5)
plt.plot(order, val_r2_obs[1])
plt.plot(order, val_r2_nl[1])
plt.plot(order, val_r2_25[1])
plt.plot(order, val_r2_50[1])
plt.legend(["Luenberg Observer", "NLESO, trainable $\delta$", "NLESO, fixed $\delta$=0.25", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.3,0.9)
plt.grid(True)
plt.title("Different observer on triple layer (validation r2, data: outer_21)")
plt.xlabel("Order")
plt.ylabel("R2")

plt.savefig('../figs/nonlinear/outer_21/triple_all_r2', dpi=300)

# %%
order = [3, 5, 7, 9, 11, 13, 15]
train_loss_obs = [[0.21,0.205,0.166,0.155,0.155,0.163,0.147], [0.225,0.225,0.185,0.169,0.174,0.164,0.16]]
val_loss_obs = [[0.205,0.198,0.159,0.147,0.14,0.149,0.137], [0.218,0.219,0.176,0.162,0.163,0.15,0.147]]
val_r2_obs = [[0.59,0.616,0.751,0.788,0.808,0.783,0.816], [0.538,0.534,0.698,0.741,0.74,0.78,0.789]]

train_loss_50 = [[0.161,0.159,0.157,0.151,0.128,0.131,0.128], [0.177,0.175,0.16,0.166,0.151,0.132,0.138]]
val_loss_50 = [[0.154,0.154,0.15,0.146,0.118,0.124,0.117], [0.171,0.17,0.155,0.16,0.148,0.123,0.132]]
val_r2_50 = [[0.768,0.769,0.78,0.791,0.864,0.848,0.865], [0.715,0.716,0.764,0.749,0.785,0.852,0.83]]

plt.figure(0)
plt.plot(order, train_loss_obs[0])
plt.plot(order, train_loss_50[0])
plt.legend(["Luenberg Observer", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.1,0.3)
plt.grid(True)
plt.title("Different observer on single layer (training, data: inner_07)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/inner_07/single_all_train', dpi=300)

plt.figure(1)
plt.plot(order, val_loss_obs[0])
plt.plot(order, val_loss_50[0])
plt.legend(["Luenberg Observer", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.1,0.3)
plt.grid(True)
plt.title("Different observer on single layer (validation, data: inner_07)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/inner_07/single_all_val', dpi=300)

plt.figure(2)
plt.plot(order, val_r2_obs[0])
plt.plot(order, val_r2_50[0])
plt.legend(["Luenberg Observer", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.5,0.9)
plt.grid(True)
plt.title("Different observer on single layer (validation r2, data: inner_07)")
plt.xlabel("Order")
plt.ylabel("R2")

plt.savefig('../figs/nonlinear/inner_07/single_all_r2', dpi=300)

plt.figure(3)
plt.plot(order, train_loss_obs[1])
plt.plot(order, train_loss_50[1])
plt.legend(["Luenberg Observer", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.1,0.3)
plt.grid(True)
plt.title("Different observer on triple layer (training, data: inner_07)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/inner_07/triple_all_train', dpi=300)

plt.figure(4)
plt.plot(order, val_loss_obs[1])
plt.plot(order, val_loss_50[1])
plt.legend(["Luenberg Observer", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.1,0.3)
plt.grid(True)
plt.title("Different observer on triple layer (validation, data: inner_07)")
plt.xlabel("Order")
plt.ylabel("RMSE loss")

plt.savefig('../figs/nonlinear/inner_07/triple_all_val', dpi=300)

plt.figure(5)
plt.plot(order, val_r2_obs[1])
plt.plot(order, val_r2_50[1])
plt.legend(["Luenberg Observer", "NLESO, fixed $\delta$=0.5"])
plt.ylim(0.5,0.9)
plt.grid(True)
plt.title("Different observer on triple layer (validation r2, data: inner_07)")
plt.xlabel("Order")
plt.ylabel("R2")

plt.savefig('../figs/nonlinear/inner_07/triple_all_r2', dpi=300)
