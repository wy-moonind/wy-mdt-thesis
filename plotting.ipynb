# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import sys
import seaborn as sn

def norm(x):
    xmax = max(x)
    xmin = min(x)
    for i in range(len(x)):
        x[i] = (x[i] - xmin)/(xmax - xmin)
    return x

# %%
order = [3, 5, 7, 9, 11, 13, 15, 17, 19]
layer = [1, 2, 3, 4, 5, 6, 7]

order_ret_07 = [0.857571429, 0.888857143, 0.904714286, 0.901428571, 0.916714286, 0.923285714, 0.924857143, 0.923142857, 0.926857143]
layer_ret_07 = [0.9205, 0.922, 0.92525, 0.92575, 0.92725, 0.9265, 0.9245]
order_ret_21 = [0.529142857, 0.566714286, 0.614614286, 0.673571429, 0.691714286, 0.723285714, 0.732142857, 0.745714286, 0.736428571]
layer_ret_21 = [0.7115, 0.73425, 0.73825, 0.7315, 0.73925, 0.744, 0.742]

order_ret_07 = norm(order_ret_07)
order_ret_21 = norm(order_ret_21)
layer_ret_07 = norm(layer_ret_07)
layer_ret_21 = norm(layer_ret_21)

plt.figure(0)
plt.plot(order, order_ret_07)
plt.plot(order, order_ret_21)
plt.xlabel("Order")
plt.ylabel("R2 score")
plt.legend(["Outer race fd07", "Outer race fd21"])
plt.grid(True)
plt.savefig('../figs/order_var', dpi=300, bbox_inches='tight')

plt.figure(1)
plt.plot(layer, layer_ret_07)
plt.plot(layer, layer_ret_21)
plt.xlabel("Layer")
plt.ylabel("R2 score")
plt.legend(["Outer race fd07", "Outer race fd21"])
plt.grid(True)
plt.savefig('../figs/layer_var', dpi=300, bbox_inches='tight')

# %%
array1 = [[0.890, 0.879, 0.903, 0.884, 0.881, 0.898, 0.893, 0.922, 0.915],
         [0.907, 0.904,	0.921, 0.914, 0.925, 0.92,	0.923, 0.914, 0.931],
         [0.905, 0.905,	0.914, 0.905, 0.913, 0.927,	0.923, 0.923, 0.928],
         [0.866, 0.863,	0.912, 0.915, 0.911, 0.922,	0.931, 0.927, 0.919],
         [0.821, 0.895,	0.892, 0.906, 0.915, 0.93,	0.927, 0.922, 0.93],
         [0.759, 0.912, 0.898, 0.899, 0.915, 0.924, 0.922 ,0.926, 0.934], 
         [0.837, 0.831, 0.881, 0.852, 0.918, 0.917, 0.926, 0.928, 0.927]]
array2 = [[0.52, 0.579, 0.661, 0.692, 0.724, 0.713, 0.722, 0.702, 0.709], 
          [0.503, 0.563, 0.672, 0.639, 0.701, 0.723, 0.72, 0.662, 0.751], 
          [0.532, 0.534, 0.634, 0.68, 0.694, 0.722, 0.739, 0.761, 0.731], 
          [0.537, 0.548, 0.601, 0.697, 0.687, 0.704, 0.738, 0.724, 0.76], 
          [0.522, 0.593, 0.622, 0.681, 0.725, 0.728, 0.756, 0.737, 0.736], 
          [0.53, 0.606, 0.5193, 0.672, 0.653, 0.745, 0.709, 0.796, 0.726], 
          [0.56, 0.544, 0.593, 0.654, 0.658, 0.728, 0.741, 0.757, 0.742]]

df_cm = pd.DataFrame(array1, index = [i for i in "1234567"],
                  columns = ["3", "5", "7", "9", "11", "13", "15", "17", "19"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.xlabel("Order")
plt.ylabel("Layers")
plt.savefig('../figs/outer07_heat_r2', dpi=300, bbox_inches='tight')

# %%
order = [3, 5, 7, 9, 11, 13, 15]
# outer07 parallel
layer1 = [[0.125, 0.129, 0.119, 0.129, 0.128, 0.116, 0.121],
            [0.114, 0.118, 0.108, 0.115, 0.119, 0.108, 0.11],
            [0.89, 0.879, 0.903, 0.884, 0.881, 0.898, 0.893]] 
p_layer2 = [[0.197,	0.166,	0.182,	0.158,	0.167,	0.196,	0.198],
            [0.161,	0.142,	0.157,	0.162,	0.164,	0.157,	0.164],
            [0.764,	0.786,	0.779,	0.771,	0.771,	0.792,	0.763]]
p_layer3 = [[0.196,0.204,	0.147,	0.125,	0.138,	0.099,	0.122],
            [0.173,	0.153,	0.13,	0.128,	0.134,	0.109,	0.136],
            [0.74,0.788,	0.849,	0.853,	0.844,	0.886,	0.813]]
p_layer4 = [[0.184,	0.186,	0.116,	0.126,	0.174,	0.19,	0.202],
            [0.17,0.167,	0.131,	0.129,	0.148,	0.158,	0.186],
            [0.73,	0.742,	0.831,	0.85,	0.793,	0.773,	0.704]]
p_layer5 = [[0.201,	0.189,	0.199,	0.203,	0.119,	0.194,	0.182],
            [0.17,0.143,	0.17,	0.169,	0.126,	0.162,	0.167],
            [0.739,	0.828,	0.746,	0.749,	0.861,	0.76,	0.766]]

# outer21 parallel
# layer1 = [[0.23, 0.216, 0.206, 0.19, 0.184, 0.182, 0.183],
#           [0.214, 0.203, 0.182, 0.173, 0.164, 0.167, 0.165],
#           [0.52, 0.579, 0.661, 0.692, 0.724, 0.716, 0.722]]
# p_layer2 = [[0.29,	0.296,	0.288,	0.287,	0.276,	0.289,	0.281],
#             [0.247,	0.251,	0.211,	0.241,	0.238,	0.242,	0.237],
#             [0.368,	0.36,	0.544,	0.402,	0.418,	0.399,	0.425]]
# p_layer3 = [[0.289,	0.271,	0.283,	0.282,	0.272,	0.282,	0.276],
#             [0.234,	0.228,	0.237,	0.238,	0.228,	0.233,	0.223],
#             [0.431,	0.464,	0.418,	0.415,	0.465,	0.439,	0.486]]
# p_layer4 = [[0.27 , 0.275,	0.193,	0.233,	0.274,	0.184,	0.209],
#             [0.22 , 0.225,	0.173,	0.203,	0.239,	0.17,	0.184],
#             [0.494,	0.485, 0.689,	0.567,	0.41,	0.698,	0.643]]
# p_layer5 = [[0.282,	0.189,	0.28,	0.257,	0.191,	0.18,	0.194],
#             [0.239,	0.172,	0.254,	0.217,	0.171,	0.168,	0.17],
#             [0.415,	0.69,	0.341,	0.512,	0.691,	0.707,	0.696]]
plt.figure(0)
plt.plot(order,layer1[0])
plt.plot(order,p_layer2[0])
plt.plot(order,p_layer3[0])
plt.plot(order,p_layer4[0])
plt.plot(order,p_layer5[0])
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Training RMSE")
plt.legend(['Layer=1','Layer=2','Layer=3','Layer=4','Layer=5'],
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
# plt.savefig('../figs/outer07_pa_tl', dpi=300, bbox_inches='tight')

plt.figure(1)
plt.plot(order,layer1[1])
plt.plot(order,p_layer2[1])
plt.plot(order,p_layer3[1])
plt.plot(order,p_layer4[1])
plt.plot(order,p_layer5[1])
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation RMSE")
plt.legend(['Layer=1','Layer=2','Layer=3','Layer=4','Layer=5'],
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
# plt.savefig('../figs/outer07_pa_vl', dpi=300, bbox_inches='tight')

plt.figure(2)
plt.plot(order,layer1[2])
plt.plot(order,p_layer2[2])
plt.plot(order,p_layer3[2])
plt.plot(order,p_layer4[2])
plt.plot(order,p_layer5[2])
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation R2 score")
plt.legend(['Layer=1','Layer=2','Layer=3','Layer=4','Layer=5'],
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
# plt.savefig('../figs/outer07_pa_v2', dpi=300, bbox_inches='tight')

# %%
order = [3, 5, 7, 9, 11, 13, 15]
# outer07 serial
# layer1 = [[0.125, 0.129, 0.119, 0.129, 0.128, 0.116, 0.121],
#             [0.114, 0.118, 0.108, 0.115, 0.119, 0.108, 0.11],
#             [0.89, 0.879, 0.903, 0.884, 0.881, 0.898, 0.893]] 
# s_layer2 = [[0.112,0.113,	0.101,	0.106,	0.097,	0.099,	0.098],
#             [0.105,0.106,	0.096,	0.1,	0.094,	0.096,	0.095],
#             [0.907,0.904,	0.921,	0.914,	0.925,	0.92,	0.923]]
# s_layer3 = [[0.113,0.117,	0.11,	0.111,	0.101,	0.094,	0.098],
#             [0.106,0.106,	0.1,	0.106,	0.101,	0.092,	0.095],
#             [0.905,0.905,	0.914,	0.905,	0.913,	0.927,	0.923]]
# s_layer4 = [[0.138,0.131,	0.106,	0.105,	0.104,	0.098,	0.094],
#             [0.127,	0.128,	0.101,	0.099,	0.102,	0.096,	0.089],
#             [0.866,	0.863,	0.912,	0.915,	0.911,	0.922,	0.931]]
# s_layer5 = [[0.164,	0.118,	0.117,	0.114,	0.101,	0.091,	0.094],
#             [0.144,	0.11,	0.113,	0.104,	0.1,	0.089,	0.092],
#             [0.821,	0.895,	0.892,	0.906,	0.915,	0.93,	0.927]]

# outer21 serial
layer1 = [[0.23, 0.216, 0.206, 0.19, 0.184, 0.182, 0.183],
          [0.214, 0.203, 0.182, 0.173, 0.164, 0.167, 0.165],
          [0.52, 0.579, 0.661, 0.692, 0.724, 0.716, 0.722]]
s_layer2 = [[0.232, 0.222, 0.192, 0.204, 0.186, 0.181, 0.186],
            [0.22, 0.207, 0.179, 0.187, 0.17, 0.164, 0.165],
            [0.503, 0.563, 0.672, 0.639, 0.701, 0.723, 0.72]]
s_layer3 = [[0.232, 0.226, 0.207, 0.199, 0.191, 0.18, 0.175],
            [0.214, 0.213, 0.189, 0.176, 0.173, 0.164, 0.16],
            [0.532, 0.534, 0.634, 0.68, 0.694, 0.722, 0.739]]
s_layer4 = [[0.232, 0.227, 0.212, 0.192, 0.194, 0.19, 0.177],
            [0.213, 0.21, 0.197, 0.172, 0.175, 0.17, 0.16],
            [0.537, 0.548, 0.601, 0.697, 0.687, 0.704, 0.738]]
s_layer5 = [[0.234, 0.219, 0.213, 0.198, 0.182, 0.181, 0.186],
            [0.216, 0.199, 0.192, 0.176, 0.163, 0.163, 0.154],
            [0.522, 0.593, 0.622, 0.681, 0.725, 0.728, 0.756]]

plt.figure(0)
plt.plot(order,layer1[0])
plt.plot(order,s_layer2[0])
plt.plot(order,s_layer3[0])
plt.plot(order,s_layer4[0])
plt.plot(order,s_layer5[0])
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Training RMSE")
plt.legend(['Layer=1','Layer=2','Layer=3','Layer=4','Layer=5'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer21_hype_tl', dpi=300, bbox_inches='tight')

plt.figure(1)
plt.plot(order,layer1[1])
plt.plot(order,s_layer2[1])
plt.plot(order,s_layer3[1])
plt.plot(order,s_layer4[1])
plt.plot(order,s_layer5[1])
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation RMSE")
plt.legend(['Layer=1','Layer=2','Layer=3','Layer=4','Layer=5'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer21_hype_vl', dpi=300, bbox_inches='tight')

plt.figure(2)
plt.plot(order,layer1[2])
plt.plot(order,s_layer2[2])
plt.plot(order,s_layer3[2])
plt.plot(order,s_layer4[2])
plt.plot(order,s_layer5[2])
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation R2 score")
plt.legend(['Layer=1','Layer=2','Layer=3','Layer=4','Layer=5'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer21_hype_v2', dpi=300, bbox_inches='tight')

# %%
# parallel/serial
order = [3, 5, 7, 9, 11, 13, 15]
# outer07 serial
# layer1 = [[0.125, 0.129, 0.119, 0.129, 0.128, 0.116, 0.121],
#             [0.114, 0.118, 0.108, 0.115, 0.119, 0.108, 0.11],
#             [0.89, 0.879, 0.903, 0.884, 0.881, 0.898, 0.893]] 
# s_layer2 = [[0.112,0.113,	0.101,	0.106,	0.097,	0.099,	0.098],
#             [0.105,0.106,	0.096,	0.1,	0.094,	0.096,	0.095],
#             [0.907,0.904,	0.921,	0.914,	0.925,	0.92,	0.923]]
# s_layer3 = [[0.113,0.117,	0.11,	0.111,	0.101,	0.094,	0.098],
#             [0.106,0.106,	0.1,	0.106,	0.101,	0.092,	0.095],
#             [0.905,0.905,	0.914,	0.905,	0.913,	0.927,	0.923]]
# s_layer4 = [[0.138,0.131,	0.106,	0.105,	0.104,	0.098,	0.094],
#             [0.127,	0.128,	0.101,	0.099,	0.102,	0.096,	0.089],
#             [0.866,	0.863,	0.912,	0.915,	0.911,	0.922,	0.931]]
# s_layer5 = [[0.164,	0.118,	0.117,	0.114,	0.101,	0.091,	0.094],
#             [0.144,	0.11,	0.113,	0.104,	0.1,	0.089,	0.092],
#             [0.821,	0.895,	0.892,	0.906,	0.915,	0.93,	0.927]]
# p_layer2 = [[0.197,	0.166,	0.182,	0.158,	0.167,	0.196,	0.198],
#             [0.161,	0.142,	0.157,	0.162,	0.164,	0.157,	0.164],
#             [0.764,	0.786,	0.779,	0.771,	0.771,	0.792,	0.763]]
# p_layer3 = [[0.196,0.204,	0.147,	0.125,	0.138,	0.099,	0.122],
#             [0.173,	0.153,	0.13,	0.128,	0.134,	0.109,	0.136],
#             [0.74,0.788,	0.849,	0.853,	0.844,	0.886,	0.813]]
# p_layer4 = [[0.184,	0.186,	0.116,	0.126,	0.174,	0.19,	0.202],
#             [0.17,0.167,	0.131,	0.129,	0.148,	0.158,	0.186],
#             [0.73,	0.742,	0.831,	0.85,	0.793,	0.773,	0.704]]
# p_layer5 = [[0.201,	0.189,	0.199,	0.203,	0.119,	0.194,	0.182],
#             [0.17,0.143,	0.17,	0.169,	0.126,	0.162,	0.167],
#             [0.739,	0.828,	0.746,	0.749,	0.861,	0.76,	0.766]]
# outer21 serial
layer1 = [[0.23, 0.216, 0.206, 0.19, 0.184, 0.182, 0.183],
          [0.214, 0.203, 0.182, 0.173, 0.164, 0.167, 0.165],
          [0.52, 0.579, 0.661, 0.692, 0.724, 0.716, 0.722]]
s_layer2 = [[0.232, 0.222, 0.192, 0.204, 0.186, 0.181, 0.186],
            [0.22, 0.207, 0.179, 0.187, 0.17, 0.164, 0.165],
            [0.503, 0.563, 0.672, 0.639, 0.701, 0.723, 0.72]]
s_layer3 = [[0.232, 0.226, 0.207, 0.199, 0.191, 0.18, 0.175],
            [0.214, 0.213, 0.189, 0.176, 0.173, 0.164, 0.16],
            [0.532, 0.534, 0.634, 0.68, 0.694, 0.722, 0.739]]
s_layer4 = [[0.232, 0.227, 0.212, 0.192, 0.194, 0.19, 0.177],
            [0.213, 0.21, 0.197, 0.172, 0.175, 0.17, 0.16],
            [0.537, 0.548, 0.601, 0.697, 0.687, 0.704, 0.738]]
s_layer5 = [[0.234, 0.219, 0.213, 0.198, 0.182, 0.181, 0.186],
            [0.216, 0.199, 0.192, 0.176, 0.163, 0.163, 0.154],
            [0.522, 0.593, 0.622, 0.681, 0.725, 0.728, 0.756]]
p_layer2 = [[0.29,	0.296,	0.288,	0.287,	0.276,	0.289,	0.281],
            [0.247,	0.251,	0.211,	0.241,	0.238,	0.242,	0.237],
            [0.368,	0.36,	0.544,	0.402,	0.418,	0.399,	0.425]]
p_layer3 = [[0.289,	0.271,	0.283,	0.282,	0.272,	0.282,	0.276],
            [0.234,	0.228,	0.237,	0.238,	0.228,	0.233,	0.223],
            [0.431,	0.464,	0.418,	0.415,	0.465,	0.439,	0.486]]
p_layer4 = [[0.27 , 0.275,	0.193,	0.233,	0.274,	0.184,	0.209],
            [0.22 , 0.225,	0.173,	0.203,	0.239,	0.17,	0.184],
            [0.494,	0.485, 0.689,	0.567,	0.41,	0.698,	0.643]]
p_layer5 = [[0.282,	0.189,	0.28,	0.257,	0.191,	0.18,	0.194],
            [0.239,	0.172,	0.254,	0.217,	0.171,	0.168,	0.17],
            [0.415,	0.69,	0.341,	0.512,	0.691,	0.707,	0.696]]

plt.figure(0)
plt.plot(order,layer1[0], marker='+')
plt.plot(order,s_layer2[0], marker='o')
plt.plot(order,s_layer3[0], marker='o')
plt.plot(order,s_layer4[0], marker='o')
plt.plot(order,s_layer5[0], marker='o')
plt.plot(order,p_layer2[0], marker='x')
plt.plot(order,p_layer3[0], marker='x')
plt.plot(order,p_layer4[0], marker='x')
plt.plot(order,p_layer5[0], marker='x')
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Training RMSE")
plt.legend(['Layer=1','Layer=2, serial','Layer=3, serial','Layer=4, serial','Layer=5, serial',
            'Layer=2, parallel','Layer=3, parallel','Layer=4, parallel','Layer=5, parallel'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer21_sp_compare_tl', dpi=300, bbox_inches='tight')

plt.figure(1)
plt.plot(order,layer1[1], marker='+')
plt.plot(order,s_layer2[1], marker='o')
plt.plot(order,s_layer3[1], marker='o')
plt.plot(order,s_layer4[1], marker='o')
plt.plot(order,s_layer5[1], marker='o')
plt.plot(order,p_layer2[1], marker='x')
plt.plot(order,p_layer3[1], marker='x')
plt.plot(order,p_layer4[1], marker='x')
plt.plot(order,p_layer5[1], marker='x')
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation RMSE")
plt.legend(['Layer=1','Layer=2, serial','Layer=3, serial','Layer=4, serial','Layer=5, serial',
            'Layer=2, parallel','Layer=3, parallel','Layer=4, parallel','Layer=5, parallel'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer21_sp_compare_vl', dpi=300, bbox_inches='tight')

plt.figure(2)
plt.plot(order,layer1[2], marker='+')
plt.plot(order,s_layer2[2], marker='o')
plt.plot(order,s_layer3[2], marker='o')
plt.plot(order,s_layer4[2], marker='o')
plt.plot(order,s_layer5[2], marker='o')
plt.plot(order,p_layer2[2], marker='x')
plt.plot(order,p_layer3[2], marker='x')
plt.plot(order,p_layer4[2], marker='x')
plt.plot(order,p_layer5[2], marker='x')
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation R2 score")
plt.legend(['Layer=1','Layer=2, serial','Layer=3, serial','Layer=4, serial','Layer=5, serial',
            'Layer=2, parallel','Layer=3, parallel','Layer=4, parallel','Layer=5, parallel'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer21_sp_compare_v2', dpi=300, bbox_inches='tight')

# %%
# single layer with nleso
order = [3, 5, 7, 9, 11, 13, 15]

# with_lso = [[0.244, 0.242, 0.243, 0.243, 0.21, 0.21, 0.214],
#             [0.232, 0.231, 0.231, 0.232, 0.197, 0.194, 0.201],
#             [0.447, 0.451, 0.451, 0.449, 0.604, 0.611, 0.585]]  # with observer outer 21
# with_nlso_t = [[0.241, 0.238, 0.208, 0.196, 0.186, 0.187, 0.187],
#                [0.219, 0.221, 0.192, 0.172, 0.164, 0.172, 0.166],
#                [0.509, 0.502, 0.618, 0.696, 0.724, 0.711, 0.719]]
# with_nlso_f25 = [[0.244, 0.239, 0.243, 0.208, 0.194, 0.189, 0.188],
#                  [0.226, 0.221, 0.228, 0.183, 0.172, 0.166, 0.167],
#                  [0.476, 0.504, 0.467, 0.656, 0.699, 0.713, 0.715]]
# with_nlso_f50 = [[0.23, 0.216, 0.206, 0.19, 0.184, 0.182, 0.183],
#                  [0.214, 0.203, 0.182, 0.173, 0.164, 0.167, 0.165],
#                  [0.52, 0.579, 0.661, 0.692, 0.724, 0.716, 0.722]]

with_lso = [[0.125, 0.129, 0.119, 0.129, 0.128, 0.116, 0.121],
            [0.114, 0.118, 0.108, 0.115, 0.119, 0.108, 0.11],
            [0.89, 0.879, 0.903, 0.884, 0.881, 0.898, 0.893]]  # with observer outer 07
with_nlso_t = [[0.116, 0.11, 0.112, 0.109, 0.111, 0.106, 0.104],
               [0.108, 0.104, 0.103, 0.102, 0.099, 0.098, 0.097],
               [0.901, 0.909, 0.912, 0.91, 0.914, 0.92, 0.92]]
with_nlso_f25 = [[0.113, 0.11, 0.107, 0.106, 0.108, 0.104, 0.094],
                 [0.103, 0.101, 0.101, 0.096, 0.1, 0.097, 0.095],
                 [0.913, 0.915, 0.911, 0.922, 0.914, 0.92, 0.922]]
with_nlso_f50 = [[0.114, 0.111, 0.105, 0.106, 0.098, 0.101, 0.094],
                 [0.105, 0.102, 0.1, 0.098, 0.097, 0.094, 0.095],
                 [0.908, 0.912, 0.915, 0.919, 0.92, 0.923, 0.922]]

plt.figure(0)
plt.plot(order, with_lso[0])
plt.plot(order, with_nlso_t[0])
plt.plot(order, with_nlso_f25[0])
plt.plot(order, with_nlso_f50[0])
# plt.ylim(0.09, 0.135)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Training RMSE")
plt.legend(["Linear observer", "NLESO(trainable $\delta$)",
           "NLESO($\delta = 0.25$)", "NLESO($\delta = 0.5$)"])
plt.savefig('../figs/outer07_so_train', dpi=300, bbox_inches='tight')

plt.figure(1)
plt.plot(order, with_lso[1])
plt.plot(order, with_nlso_t[1])
plt.plot(order, with_nlso_f25[1])
plt.plot(order, with_nlso_f50[1])
# plt.ylim(0.09, 0.135)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Validation RMSE")
plt.legend(["Linear observer", "NLESO(trainable $\delta$)",
           "NLESO($\delta = 0.25$)", "NLESO($\delta = 0.5$)"])
plt.savefig('../figs/outer07_so_valloss', dpi=300, bbox_inches='tight')

plt.figure(2)
plt.plot(order, with_lso[2])
plt.plot(order, with_nlso_t[2])
plt.plot(order, with_nlso_f25[2])
plt.plot(order, with_nlso_f50[2])
# plt.ylim(0.83, 0.94)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Validation R2")
plt.legend(["Linear observer", "NLESO(trainable $\delta$)",
           "NLESO($\delta = 0.25$)", "NLESO($\delta = 0.5$)"])
plt.savefig('../figs/outer07_so_valR2', dpi=300, bbox_inches='tight')

# %%
# single layer with linear observer
order = [3, 5, 7, 9, 11, 13, 15]
# baseline = [[0.344, 0.327, 0.328, 0.33, 0.325, 0.298, 0.306],
#             [0.337, 0.32, 0.312, 0.318, 0.315, 0.269, 0.282],
#             [-0.158, -0.046, 0.005, -0.032, -0.017, 0.257, 0.184]]  # without observer outer 21

# with_lso = [[0.244, 0.242, 0.243, 0.243, 0.21, 0.21, 0.214],
#             [0.232, 0.231, 0.231, 0.232, 0.197, 0.194, 0.201],
#             [0.447, 0.451, 0.451, 0.449, 0.604, 0.611, 0.585]]  # with observer outer 21

baseline = [[0.36, 0.347, 0.23, 0.217, 0.224, 0.215, 0.219],
            [0.343, 0.347, 0.212, 0.208, 0.187, 0.191, 0.183],
            [0.064, 0.041, 0.613, 0.625, 0.693, 0.684, 0.699]] # without observer outer 07

with_lso = [[0.125, 0.129, 0.119, 0.129, 0.128, 0.116, 0.121],
            [0.114, 0.118, 0.108, 0.115, 0.119, 0.108, 0.11],
            [0.89, 0.879, 0.903, 0.884, 0.881, 0.898, 0.893]]  # with observer outer 07

plt.figure(0)
plt.plot(order, baseline[0])
plt.plot(order, with_lso[0])
plt.ylim(0, 0.5)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Training RMSE")
plt.legend(["Baseline(w/o observer)", "With linear observer"])
plt.savefig('../figs/outer07_lo_train', dpi=300)

plt.figure(1)
plt.plot(order, baseline[1])
plt.plot(order, with_lso[1])
plt.ylim(0, 0.5)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Validation RMSE")
plt.legend(["Baseline(w/o observer)", "With linear observer"])
plt.savefig('../figs/outer07_lo_valloss', dpi=300)

plt.figure(2)
plt.plot(order, baseline[2])
plt.plot(order, with_lso[2])
plt.ylim(0, 1)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Validation R2")
plt.legend(["Baseline(w/o observer)", "With linear observer"])
plt.savefig('../figs/outer07_lo_valR2', dpi=300)

# %%
# activation compare
order = [3, 5, 7, 9, 11, 13, 15]
# baseline = [[0.344, 0.327, 0.328, 0.33, 0.325, 0.298, 0.306],
#             [0.337, 0.32, 0.312, 0.318, 0.315, 0.269, 0.282],
#             [-0.158, -0.046, 0.005, -0.032, -0.017, 0.257, 0.184]]
# tanh = [[0.333, 0.333, 0.328, 0.323, 0.304, 0.324, 0.31],
#         [0.325, 0.328, 0.313, 0.307, 0.29, 0.31, 0.286],
#         [-0.079, -0.098, 0.001, 0.029, 0.114, 0.016, 0.156]]
# relu = [[0.332, 0.328, 0.33, 0.33, 0.328, 0.32, 0.305],
#         [0.323, 0.31, 0.318, 0.316, 0.314, 0.298, 0.274],
#         [-0.065, 0.019, -0.032, -0.02, -0.008, 0.092, 0.226]]
# softp = [[0.334, 0.332, 0.331, 0.317, 0.309, 0.319, 0.308],
#          [0.326, 0.321, 0.319, 0.303, 0.285, 0.301, 0.283],
#          [-0.086, -0.053, -0.038, 0.11, 0.167, 0.073, 0.172]] # outer 21

baseline = [[0.36, 0.347, 0.23, 0.217, 0.224, 0.215, 0.219],
            [0.343, 0.347, 0.212, 0.208, 0.187, 0.191, 0.183],
            [0.064, 0.041, 0.613, 0.625, 0.693, 0.684, 0.699]]
tanh = [[0.359, 0.363, 0.212, 0.212, 0.214, 0.216, 0.21],
        [0.343, 0.347, 0.186, 0.181, 0.198, 0.192, 0.184],
        [0.065, 0.04, 0.694, 0.707, 0.649, 0.666, 0.703]]
relu = [[0.364, 0.375, 0.381, 0.252, 0.21, 0.211, 0.211],
        [0.348, 0.358, 0.363, 0.208, 0.194, 0.191, 0.187],
        [0.038, -0.023, -0.056, 0.631, 0.663, 0.66, 0.677]]
softp = [[0.367, 0.364, 0.216, 0.216, 0.22, 0.223, 0.211],
         [0.351, 0.348, 0.192, 0.185, 0.191, 0.195, 0.186],
         [0.019, 0.0383, 0.673, 0.698, 0.676, 0.674, 0.685]] # outer 07

# train loss
plt.figure(0)
plt.plot(order, baseline[0])
plt.plot(order, tanh[0])
plt.plot(order, relu[0])
plt.plot(order, softp[0])
plt.ylim(0.1, 0.4)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Training RMSE")
plt.legend(["Baseline(w/o activation)", "Tanh activation", "ReLU activation", "SoftPlus activation"])
plt.savefig('../figs/outer07_acti_trainloss', dpi=300)

plt.figure(1)
plt.plot(order, baseline[1])
plt.plot(order, tanh[1])
plt.plot(order, relu[1])
plt.plot(order, softp[1])
plt.ylim(0.1, 0.4)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Validation RMSE")
plt.legend(["Baseline(w/o activation)", "Tanh activation", "ReLU activation", "SoftPlus activation"])
plt.savefig('../figs/outer07_acti_valloss', dpi=300)

plt.figure(2)
plt.plot(order, baseline[2])
plt.plot(order, tanh[2])
plt.plot(order, relu[2])
plt.plot(order, softp[2])
plt.ylim(-0.1, 0.8)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("Validation R2")
plt.legend(["Baseline(w/o activation)", "Tanh activation", "ReLU activation", "SoftPlus activation"])
plt.savefig('../figs/outer07_acti_valr2', dpi=300)

# %%
# without observer
order = [3, 5, 7, 9, 11, 13, 15]
# outer07
train_loss = [0.36, 0.347, 0.23, 0.217, 0.224, 0.215, 0.219]
val_loss = [0.343, 0.347, 0.212, 0.208, 0.187, 0.191, 0.183]
val_r2 = [0.064, 0.041, 0.613, 0.625, 0.693, 0.684, 0.699]

# outer21
# train_loss = [0.344, 0.327, 0.328, 0.33, 0.325, 0.298, 0.306]
# val_loss = [0.337, 0.32, 0.312, 0.318, 0.315, 0.269, 0.282]
# val_r2 = [-0.158, -0.046, 0.005, -0.032, -0.017, 0.257, 0.184]


plt.figure(0)
plt.plot(order, train_loss)
plt.plot(order, val_loss)
plt.plot(order, val_r2)

plt.legend(["Training RMSE Loss", "Validation RMSE Loss", "Validation R2"])
plt.ylim(-0, 0.8)
plt.grid(True)
plt.xlabel("Order")
plt.ylabel("RMSE/R-squared")
plt.savefig('../figs/outer07_wo', dpi=300)
