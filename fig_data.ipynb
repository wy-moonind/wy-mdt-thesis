# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import sys
import seaborn as sn

parameters = {'axes.labelsize': 15,
        'axes.titlesize': 5,
        'figure.titlesize': 5,
        'xtick.labelsize': 10,
        'ytick.labelsize': 10,
        'savefig.dpi': 300,
        'figure.dpi': 300,
        'lines.linewidth': 1.5,
        'axes.linewidth': 0.4,
        'xtick.major.width': 0.4,
        'ytick.major.width': 0.4,
        'xtick.major.pad': 1,
        'ytick.major.pad': 1}
plt.rcParams.update(parameters)

# %%
order = [3, 5, 7, 9, 11, 13, 15]
# outer07
r2_3_lso = [0.903,0.8986,0.8934,0.8927,0.8742]
r2_5_lso = [0.8906,0.9004,0.895,0.9068,0.8943]
r2_7_lso = [0.9023,0.9044,0.8913,0.9013,0.8915]
r2_9_lso = [0.9034,0.9064,0.9002,0.8976,0.904]
r2_11_lso = [0.8952,0.9117,0.8957,0.8997,0.9014]
r2_13_lso = [0.8992,0.9011,0.8768,0.8969,0.9048]
r2_15_lso = [0.8962,0.8995,0.8988,0.8981,0.8986]
r2_3_nlso = [0.9281,0.4398,0.9313,0.2764,0.2929]
r2_5_nlso = [0.93,0.925,-0.2106,0.9337,0.6378]
r2_7_nlso = [-0.0922,0.9273,0.9333,0.9256,0.929]
r2_9_nlso = [0.9295,0.9033,0.9327,0.7344,0.3033]
r2_11_nlso = [0.9298,0.9345,0.9313,0.8434,0.5769]
r2_13_nlso = [0.9306,0.5841,0.5414,0.9315,0.9316]
r2_15_nlso = [0.9346,0.789,0.9319,0.9326,0.8241]
r2_3_nlso50 = [0.9304,0.9322,0.9212,0.9301,0.9208]
r2_5_nlso50 = [0.9298,0.9294,0.9303,0.9297,0.932]
r2_7_nlso50 = [0.9291,0.9297,0.929,0.9304,0.9301]
r2_9_nlso50 = [0.9271,0.9192,0.9295,0.9315,0.9284]
r2_11_nlso50 = [0.932,0.9263,0.9298,0.9254,0.927]
r2_13_nlso50 = [0.9313,0.9319,0.929,0.9291,0.93]
r2_15_nlso50 = [0.9308,0.9307,0.9323,0.9337,0.9311]

# outer21
# r2_3_lso = [0.546,0.5683,0.5556,0.5589,0.5602]
# r2_5_lso = [0.5579,0.5543,0.5165,0.5605,0.551]
# r2_7_lso = [0.5593,0.5598,0.5568,0.6199,0.5666]
# r2_9_lso = [0.6355,0.625,0.6185,0.5667,0.5952]
# r2_11_lso = [0.6715,0.5845,0.6404,0.5678,0.68]
# r2_13_lso = [0.5951,0.6453,0.6282,0.6089,0.563]
# r2_15_lso = [0.5689,0.5812,0.6008,0.664,0.659]
# r2_3_nlso = [0.6919,0.3093,0.6554,0.693,0.2282]
# r2_5_nlso = [0.6872,0.6889,0.6846,0.4277,0.6843]
# r2_7_nlso = [0.6897,0.6868,0.7004,0.6837,0.6875]
# r2_9_nlso = [0.1069,0.281,-0.0809,0.2712,0.4525]
# r2_11_nlso = [0.7748,0.4279,0.2442,0.7269,0.4765]
# r2_13_nlso = [0.5631,0.365,0.4285,0.7788,0.7461]
# r2_15_nlso = [0.7726,0.7384,0.5086,0.4967,0.781]
# r2_3_nlso50 = [0.6379,0.6678,0.6712,0.6594,0.6444]
# r2_5_nlso50 = [0.6965,0.6707,0.6335,0.6816,0.6528]
# r2_7_nlso50 = [0.7018,0.6962,0.7102,0.6496,0.6962]
# r2_9_nlso50 = [0.6784,0.7371,0.713,0.7274,0.6941]
# r2_11_nlso50 = [0.7649,0.7404,0.7712,0.7557,0.7547]
# r2_13_nlso50 = [0.7546,0.7792,0.792,0.736,0.7949]
# r2_15_nlso50 = [0.7707,0.7785,0.7817,0.7856,0.7882]

r2_lso = [r2_3_lso, r2_5_lso, r2_7_lso, r2_9_lso, r2_11_lso, r2_13_lso, r2_15_lso]
r2_lso = np.array(r2_lso, dtype=float)
r2_nlso = [r2_3_nlso, r2_5_nlso, r2_7_nlso, r2_9_nlso, r2_11_nlso, r2_13_nlso, r2_15_nlso]
r2_nlso = np.array(r2_nlso, dtype=float)
r2_nlso50 = [r2_3_nlso50, r2_5_nlso50, r2_7_nlso50, r2_9_nlso50, r2_11_nlso50, r2_13_nlso50, r2_15_nlso50]
r2_nlso50 = np.array(r2_nlso50, dtype=float)

od = ['3', '5', '7', '9', '11', '13', '15']
plt.figure(figsize=(6,4))
width = 0.5
# x = np.arange(len(order))
x = np.array(order)
plt.bar(x-width, np.mean(r2_lso,axis=1).T, width, label='Linear Observer')
plt.bar(x, np.mean(r2_nlso,axis=1).T, width, label='Nonlinear Observer (trainable $\delta$)')
plt.bar(x+width, np.mean(r2_nlso50,axis=1).T, width, label='Nonlinear Observer ($\delta=0.5$)')
plt.ylabel('Test R2 score', fontsize=15)
plt.xticks(x, label=od, fontsize=15)
plt.legend(loc='upper left')
plt.xlabel('Order of model', fontsize=15)
plt.ylim(0, 1.3)
plt.savefig("../figs/outer07_bar_nlso", dpi=300, bbox_inches='tight')

# %%
# parallel/serial
order = [3, 5, 7, 9, 11, 13, 15]
# outer07 serial
# layer1 = [[],
#             [0.110 ,0.108 ,0.108 ,0.110 ,0.110 ,0.109 ,0.109 ],
#             [0.927 ,0.930 ,0.930 ,0.927 ,0.928 ,0.930 ,0.932 ]] 
# s_layer2 = [[],
#             [0.108 ,0.110 ,0.109 ,0.110 ,0.108 ,0.108 ,0.111],
#             [0.930 ,0.927 ,0.930 ,0.927 ,0.930 ,0.931 ,0.927 ]]
# s_layer5 = [[],
#             [0.112 ,0.117 ,0.115 ,0.115 ,0.112 ,0.112 ,0.105],
#             [0.924 ,0.918 ,0.920 ,0.921 ,0.924 ,0.925 ,0.935]]
# p_layer3 = [[0.196,0.204,	0.147,	0.125,	0.138,	0.099,	0.122],
#             [0.173,	0.153,	0.13,	0.128,	0.134,	0.109,	0.136],
#             [0.74,0.788,	0.849,	0.853,	0.844,	0.886,	0.813]]

# outer21 serial
layer1 = [[],
            [0.206 ,0.203 ,0.195 ,0.189 ,0.173 ,0.168 ,0.168],
            [0.656 ,0.667 ,0.691 ,0.710 ,0.757 ,0.771 ,0.781]]
s_layer5 = [[],
            [0.206 ,0.205 ,0.181 ,0.184 ,0.179 ,0.164 ,0.169],
            [0.654 ,0.659 ,0.734 ,0.723 ,0.753 ,0.780 ,0.784]]
p_layer5 = [[0.282,	0.189,	0.28,	0.257,	0.191,	0.18,	0.194],
            [0.239,	0.172,	0.254,	0.217,	0.171,	0.168,	0.17],
            [0.415,	0.69,	0.341,	0.512,	0.691,	0.707,	0.696]]


od = ['3', '5', '7', '9', '11', '13', '15']
plt.figure(figsize=(6,4))
width = 0.5
# x = np.arange(len(order))
x = np.array(order)
plt.bar(x-width, layer1[2], width, label='Layer=1')
# plt.bar(x-width, [i-0.01 for i in layer1[2]], width, label='Layer=1')
plt.bar(x, s_layer5[2], width, label='Layer=2, serial')
plt.bar(x+width, p_layer5[2], width, label='Layer=3, parallel')
plt.ylabel('Test R2 score', fontsize=15)
plt.xticks(x, label=od, fontsize=15)
plt.legend(loc='upper left')
plt.xlabel('Order of model', fontsize=15)
plt.ylim(0, 1.3)
plt.savefig("../figs/outer21_bar_sp", dpi=300, bbox_inches='tight')

# %%
order = [3, 5, 7, 9, 11, 13, 15, 17, 19]
layer = [1, 2, 3, 4, 5, 6, 7]

outer07 = [[0.927,0.93,0.93,0.927,0.928,0.93,0.932,0.925,0.927],
         [0.93,0.927,0.93,0.927,0.93,0.931,0.927,0.931,0.932],
         [0.928,0.927,0.931,0.929,0.923,0.928,0.932,0.933,0.933],
         [0.923,0.929,0.924,0.919,0.921,0.927,0.934,0.935,0.937],
         [0.924,0.918,0.92,0.921,0.924,0.925,0.935,0.939,0.938],
         [0.924,0.915,0.916,0.925,0.928,0.935,0.93,0.933,0.935], 
         [0.803,0.919,0.927,0.918,0.91,0.919,0.927,0.937,0.929]]
outer21 = [[0.656,0.667,0.691,0.71,0.757,0.771,0.781,0.774,0.793],
         [0.657,0.653,0.715,0.747,0.746,0.749,0.73,0.789,0.784],
         [0.641,0.674,0.718,0.727,0.777,0.775,0.782,0.797,0.823],
         [0.622,0.658,0.687,0.741,0.768,0.779,0.784,0.779,0.805],
         [0.654,0.659,0.734,0.723,0.753,0.78,0.784,0.782,0.799],
         [0.662,0.699,0.717,0.707,0.73,0.791,0.805,0.8,0.8], 
         [0.632,0.679,0.71,0.676,0.789,0.771,0.786,0.798,0.802]]

order_mean_07 = []
order_mean_21 = []
for i in range(9):
    subset07 = [x[i] for x in outer07]
    order_mean_07.append(np.mean(subset07))
    subset21 = [x[i] for x in outer21]
    order_mean_21.append(np.mean(subset21))
layer_mean_07 = [np.mean(j[-4:]) for j in outer07]
layer_mean_21 = [np.mean(j[-4:]) for j in outer21]

# print("order mean 07: ", order_mean_07)
# print("order mean 21: ", order_mean_21)
# print("layer mean 07: ", layer_mean_07)
# print("layer mean 21: ", layer_mean_21)

fig1 = plt.figure(figsize=(6,4))
ax = fig1.add_subplot(111)
ln1 = ax.plot(order,order_mean_07, label="Outer race, fd=0.007", color="red")
ax2 = ax.twinx()
ln2 = ax2.plot(order,order_mean_21, label="Outer race, fd=0.021", color="blue")
ax.set_xlabel("Order")
ax.set_ylabel("$R^2$ score")
lns = ln1+ln2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)
ax.grid(axis="y")
ax2.set_ylabel("$R^2$ score")
fig1.savefig('../figs/order_var', dpi=300, bbox_inches='tight')

fig2 = plt.figure(figsize=(6,4))
ax = fig2.add_subplot(111)
ln1 = ax.plot(layer,layer_mean_07, label="Outer race, fd=0.007", color="red")
ax2 = ax.twinx()
ln2 = ax2.plot(layer,layer_mean_21, label="Outer race, fd=0.021", color="blue")
ax.set_xlabel("Layer")
ax.set_ylabel("$R^2$ score")
lns = ln1+ln2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)
ax.grid(axis="y")
ax2.set_ylabel("$R^2$ score")
fig2.savefig('../figs/layer_var', dpi=300, bbox_inches='tight')

# %%
array1 = [[0.927,0.93,0.93,0.927,0.928,0.93,0.932,0.925,0.927],
         [0.93,0.927,0.93,0.927,0.93,0.931,0.927,0.931,0.932],
         [0.928,0.927,0.931,0.929,0.923,0.928,0.932,0.933,0.933],
         [0.923,0.929,0.924,0.919,0.921,0.927,0.934,0.935,0.937],
         [0.924,0.918,0.92,0.921,0.924,0.925,0.935,0.939,0.938],
         [0.924,0.915,0.916,0.925,0.928,0.935,0.93,0.933,0.935], 
         [0.803,0.919,0.927,0.918,0.91,0.919,0.927,0.937,0.929]]
array2 = [[0.656,0.667,0.691,0.71,0.757,0.771,0.781,0.774,0.793],
         [0.657,0.653,0.715,0.747,0.746,0.749,0.73,0.789,0.784],
         [0.641,0.674,0.718,0.727,0.777,0.775,0.782,0.797,0.823],
         [0.622,0.658,0.687,0.741,0.768,0.779,0.784,0.779,0.805],
         [0.654,0.659,0.734,0.723,0.753,0.78,0.784,0.782,0.799],
         [0.662,0.699,0.717,0.707,0.73,0.791,0.805,0.8,0.8], 
         [0.632,0.679,0.71,0.676,0.789,0.771,0.786,0.798,0.802]]

df_cm = pd.DataFrame(array2, index = [i for i in "1234567"],
                  columns = ["3", "5", "7", "9", "11", "13", "15", "17", "19"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.xlabel("Order")
plt.ylabel("Layers")
plt.savefig('../figs/outer21_heat_r2', dpi=300, bbox_inches='tight')

# %%
# parallel/serial
order = [3, 5, 7, 9, 11, 13, 15]
# outer07 serial
layer1 = [[],
            [0.110 ,0.108 ,0.108 ,0.110 ,0.110 ,0.109 ,0.109 ],
            [0.927 ,0.930 ,0.930 ,0.927 ,0.928 ,0.930 ,0.932 ]] 
s_layer2 = [[],
            [0.108 ,0.110 ,0.109 ,0.110 ,0.108 ,0.108 ,0.111],
            [0.930 ,0.927 ,0.930 ,0.927 ,0.930 ,0.931 ,0.927 ]]
s_layer3 = [[],
            [0.110 ,0.111 ,0.107 ,0.109 ,0.114 ,0.110 ,0.107],
            [0.928 ,0.927 ,0.931 ,0.929 ,0.923 ,0.928 ,0.932]]
s_layer4 = [[],
            [0.113 ,0.109 ,0.113 ,0.116 ,0.115 ,0.111 ,0.108 ],
            [0.923 ,0.929 ,0.924 ,0.919 ,0.921 ,0.927 ,0.934]]
s_layer5 = [[],
            [0.112 ,0.117 ,0.115 ,0.115 ,0.112 ,0.112 ,0.105],
            [0.924 ,0.918 ,0.920 ,0.921 ,0.924 ,0.925 ,0.935]]
p_layer2 = [[0.197,	0.166,	0.182,	0.158,	0.167,	0.196,	0.198],
            [0.161,	0.142,	0.157,	0.162,	0.164,	0.157,	0.164],
            [0.764,	0.786,	0.779,	0.771,	0.771,	0.792,	0.763]]
p_layer3 = [[0.196,0.204,	0.147,	0.125,	0.138,	0.099,	0.122],
            [0.173,	0.153,	0.13,	0.128,	0.134,	0.109,	0.136],
            [0.74,0.788,	0.849,	0.853,	0.844,	0.886,	0.813]]
p_layer4 = [[0.184,	0.186,	0.116,	0.126,	0.174,	0.19,	0.202],
            [0.17,0.167,	0.131,	0.129,	0.148,	0.158,	0.186],
            [0.73,	0.742,	0.831,	0.85,	0.793,	0.773,	0.704]]
p_layer5 = [[0.201,	0.189,	0.199,	0.203,	0.119,	0.194,	0.182],
            [0.17,0.143,	0.17,	0.169,	0.126,	0.162,	0.167],
            [0.739,	0.828,	0.746,	0.749,	0.861,	0.76,	0.766]]
# outer21 serial
# layer1 = [[],
#             [0.206 ,0.203 ,0.195 ,0.189 ,0.173 ,0.168 ,0.168],
#             [0.656 ,0.667 ,0.691 ,0.710 ,0.757 ,0.771 ,0.781]]
# s_layer2 = [[],
#             [0.206 ,0.207 ,0.188 ,0.176 ,0.177 ,0.176 ,0.183],
#             [0.657 ,0.653 ,0.715 ,0.747 ,0.746 ,0.749 ,0.730 ]]
# s_layer3 = [[],
#             [0.210 ,0.200 ,0.186 ,0.190 ,0.166 ,0.175 ,0.164],
#             [0.641 ,0.674 ,0.718 ,0.727 ,0.777 ,0.775 ,0.782]]
# s_layer4 = [[],
#             [0.215 ,0.204 ,0.196 ,0.178 ,0.169 ,0.165 ,0.163],
#             [0.622 ,0.658 ,0.687 ,0.741 ,0.768 ,0.779 ,0.784]]
# s_layer5 = [[],
#             [0.206 ,0.205 ,0.181 ,0.184 ,0.179 ,0.164 ,0.169],
#             [0.654 ,0.659 ,0.734 ,0.723 ,0.753 ,0.780 ,0.784]]
# p_layer2 = [[0.29,	0.296,	0.288,	0.287,	0.276,	0.289,	0.281],
#             [0.247,	0.251,	0.211,	0.241,	0.238,	0.242,	0.237],
#             [0.368,	0.36,	0.544,	0.402,	0.418,	0.399,	0.425]]
# p_layer3 = [[0.289,	0.271,	0.283,	0.282,	0.272,	0.282,	0.276],
#             [0.234,	0.228,	0.237,	0.238,	0.228,	0.233,	0.223],
#             [0.431,	0.464,	0.418,	0.415,	0.465,	0.439,	0.486]]
# p_layer4 = [[0.27 , 0.275,	0.193,	0.233,	0.274,	0.184,	0.209],
#             [0.22 , 0.225,	0.173,	0.203,	0.239,	0.17,	0.184],
#             [0.494,	0.485, 0.689,	0.567,	0.41,	0.698,	0.643]]
# p_layer5 = [[0.282,	0.189,	0.28,	0.257,	0.191,	0.18,	0.194],
#             [0.239,	0.172,	0.254,	0.217,	0.171,	0.168,	0.17],
#             [0.415,	0.69,	0.341,	0.512,	0.691,	0.707,	0.696]]


plt.figure(figsize=(6,4))
plt.plot(order,layer1[1], marker='+')
plt.plot(order,s_layer2[1], marker='o')
plt.plot(order,s_layer3[1], marker='o')
plt.plot(order,s_layer4[1], marker='o')
plt.plot(order,s_layer5[1], marker='o')
plt.plot(order,p_layer2[1], marker='x')
plt.plot(order,p_layer3[1], marker='x')
plt.plot(order,p_layer4[1], marker='x')
plt.plot(order,p_layer5[1], marker='x')
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation RMSE")
plt.legend(['Layer=1','Layer=2, serial','Layer=3, serial','Layer=4, serial','Layer=5, serial',
            'Layer=2, parallel','Layer=3, parallel','Layer=4, parallel','Layer=5, parallel'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer07_sp_compare_l', dpi=300, bbox_inches='tight')

plt.figure(figsize=(6,4))
plt.plot(order,layer1[2], marker='+')
plt.plot(order,s_layer2[2], marker='o')
plt.plot(order,s_layer3[2], marker='o')
plt.plot(order,s_layer4[2], marker='o')
plt.plot(order,s_layer5[2], marker='o')
plt.plot(order,p_layer2[2], marker='x')
plt.plot(order,p_layer3[2], marker='x')
plt.plot(order,p_layer4[2], marker='x')
plt.plot(order,p_layer5[2], marker='x')
plt.grid(True)
# plt.ylim(0, 0.5)
plt.xlabel("Order")
plt.ylabel("Validation R2 score")
plt.legend(['Layer=1','Layer=2, serial','Layer=3, serial','Layer=4, serial','Layer=5, serial',
            'Layer=2, parallel','Layer=3, parallel','Layer=4, parallel','Layer=5, parallel'], 
             bbox_to_anchor=(1,0), loc=3, borderaxespad=0)
plt.savefig('../figs/outer07_sp_compare', dpi=300, bbox_inches='tight')

# %%
label = [3, 5, 7, 9, 11, 13, 15]

# outer07 nlso
# r2_3 = [0.9304,0.9322,0.9212,0.9301,0.9208]
# r2_5 = [0.9298,0.9294,0.9303,0.9297,0.932]
# r2_7 = [0.9291,0.9297,0.929,0.9304,0.9301]
# r2_9 = [0.9271,0.9192,0.9295,0.9315,0.9284]
# r2_11 = [0.932,0.9263,0.9298,0.9254,0.927]
# r2_13 = [0.9313,0.9319,0.929,0.9291,0.93]
# r2_15 = [0.9308,0.9307,0.9323,0.9337,0.9311]
# outer21 nlso
r2_3 = [0.6379,0.6678,0.6712,0.6594,0.6444]
r2_5 = [0.6965,0.6707,0.6335,0.6816,0.6528]
r2_7 = [0.7018,0.6962,0.7102,0.6496,0.6962]
r2_9 = [0.6784,0.7371,0.713,0.7274,0.6941]
r2_11 = [0.7649,0.7404,0.7712,0.7557,0.7547]
r2_13 = [0.7546,0.7792,0.792,0.736,0.7949]
r2_15 = [0.7707,0.7785,0.7817,0.7856,0.7882]

plt.figure(figsize=(6,4))
plt.boxplot([r2_3, r2_5, r2_7, r2_9, r2_11, r2_13, r2_15], labels=label, showmeans=True)
plt.ylabel("R2 score")
plt.xlabel("Order of model")
plt.savefig("../figs/outer21_box_nlso", dpi=300, bbox_inches='tight')

# %%
order = [3, 5, 7, 9, 11, 13, 15]
# outer07 woobs
# r2_3 = [0.0186,0.032,0.0166,0.023,0.018]
# r2_5 = [0.025,0.025,0.028,0.025,0.026]
# r2_7 = [0.032,0.028,0.031,0.028,0.029]
# r2_9 = [0.034,0.241,0.033,0.028,0.031]
# r2_11 = [0.0797,0.2474,0.2297,0.2371,0.2464]
# r2_13 = [0.2414,0.2375,0.0366,0.2365,0.0415]
# r2_15 = [0.2334,0.2488,0.254,0.2364,0.2147]
# r2_3_lso = [0.903,0.8986,0.8934,0.8927,0.8742]
# r2_5_lso = [0.8906,0.9004,0.895,0.9068,0.8943]
# r2_7_lso = [0.9023,0.9044,0.8913,0.9013,0.8915]
# r2_9_lso = [0.9034,0.9064,0.9002,0.8976,0.904]
# r2_11_lso = [0.8952,0.9117,0.8957,0.8997,0.9014]
# r2_13_lso = [0.8992,0.9011,0.8768,0.8969,0.9048]
# r2_15_lso = [0.8962,0.8995,0.8988,0.8981,0.8986]

# outer21 woobs
r2_3 = [-0.0082,-0.0271,-0.0084,-0.0247,-0.013]
r2_5 = [0.0014,-0.0042,-0.0081,-0.0112,0.0052]
r2_7 = [0.0287,0.0062,0.0106,-0.0092,0.1047]
r2_9 = [0.0959,0.014,0.0042,0.0132,-0.003]
r2_11 = [0.1112,0.0245,0.014,0.1431,0.0581]
r2_13 = [0.1016,0.1606,0.1412,0.1705,0.0349]
r2_15 = [0.1062,0.1421,0.153,0.0921,0.1228]
r2_3_lso = [0.546,0.5683,0.5556,0.5589,0.5602]
r2_5_lso = [0.5579,0.5543,0.5165,0.5605,0.551]
r2_7_lso = [0.5593,0.5598,0.5568,0.6199,0.5666]
r2_9_lso = [0.6355,0.625,0.6185,0.5667,0.5952]
r2_11_lso = [0.6715,0.5845,0.6404,0.5678,0.68]
r2_13_lso = [0.5951,0.6453,0.6282,0.6089,0.563]
r2_15_lso = [0.5689,0.5812,0.6008,0.664,0.659]

r2_woobs = [r2_3, r2_5, r2_7, r2_9, r2_11, r2_13, r2_15]
r2_woobs = np.array(r2_woobs, dtype=float)
r2_lso = [r2_3_lso, r2_5_lso, r2_7_lso, r2_9_lso, r2_11_lso, r2_13_lso, r2_15_lso]
r2_lso = np.array(r2_lso, dtype=float)

# plt.figure(figsize=(6,4))
# plt.boxplot([r2_3_lso, r2_5_lso, r2_7_lso, r2_9_lso, r2_11_lso, r2_13_lso, r2_15_lso], labels=order, showmeans=True)
# plt.ylabel("R2 score")
# plt.xlabel("Order of model")
# plt.savefig("../figs/outer21_box_lso", dpi=300, bbox_inches='tight')

# plt.figure(figsize=(6,4))
# plt.plot(order, np.mean(r2_woobs,axis=1).T)
# plt.plot(order, np.mean(r2_lso,axis=1).T)
# plt.xlabel("Order of model")
# plt.ylabel("Test R2 score")
# plt.legend(["Without Observer", "Linear Observer"], loc="lower right")
# plt.grid(axis='y')
# plt.savefig("../figs/outer21_line_lso", dpi=300, bbox_inches='tight')
od = ['3', '5', '7', '9', '11', '13', '15']
plt.figure(figsize=(6,4))
width = 0.7
# x = np.arange(len(order))
x = np.array(order)
plt.bar(x-width/2, np.mean(r2_woobs,axis=1).T, width, label='Without Observer')
plt.bar(x+width/2, np.mean(r2_lso,axis=1).T, width, label='Linear Observer')
plt.ylabel('Test R2 score', fontsize=15)
plt.xticks(x, label=od, fontsize=15)
plt.legend(loc='upper left')
plt.xlabel('Order of model', fontsize=15)
plt.ylim(-0.03, 0.8)
plt.savefig("../figs/outer21_bar_lso", dpi=300, bbox_inches='tight')

# %%
order = [3, 5, 7, 9, 11, 13, 15]
# outer07 woobs
# r2_3 = [0.0186,0.032,0.0166,0.023,0.018]
# r2_5 = [0.025,0.025,0.028,0.025,0.026]
# r2_7 = [0.032,0.028,0.031,0.028,0.029]
# r2_9 = [0.034,0.241,0.033,0.028,0.031]
# r2_11 = [0.0797,0.2474,0.2297,0.2371,0.2464]
# r2_13 = [0.2414,0.2375,0.0366,0.2365,0.0415]
# r2_15 = [0.2334,0.2488,0.254,0.2364,0.2147]
# r2_3_lso = [0.903,0.8986,0.8934,0.8927,0.8742]
# r2_5_lso = [0.8906,0.9004,0.895,0.9068,0.8943]
# r2_7_lso = [0.9023,0.9044,0.8913,0.9013,0.8915]
# r2_9_lso = [0.9034,0.9064,0.9002,0.8976,0.904]
# r2_11_lso = [0.8952,0.9117,0.8957,0.8997,0.9014]
# r2_13_lso = [0.8992,0.9011,0.8768,0.8969,0.9048]
# r2_15_lso = [0.8962,0.8995,0.8988,0.8981,0.8986]
# r2_3_nlso = [0.9281,0.4398,0.9313,0.2764,0.2929]
# r2_5_nlso = [0.93,0.925,-0.2106,0.9337,0.6378]
# r2_7_nlso = [-0.0922,0.9273,0.9333,0.9256,0.929]
# r2_9_nlso = [0.9295,0.9033,0.9327,0.7344,0.3033]
# r2_11_nlso = [0.9298,0.9345,0.9313,0.8434,0.5769]
# r2_13_nlso = [0.9306,0.5841,0.5414,0.9315,0.9316]
# r2_15_nlso = [0.9346,0.789,0.9319,0.9326,0.8241]
# r2_3_nlso25 = [0.9296,0.9243,0.9322,0.8795,0.9341]
# r2_5_nlso25 = [0.9326,0.9341,0.7055,0.8057,0.932]
# r2_7_nlso25 = [0.9332,0.9355,0.934,0.9337,0.8822]
# r2_9_nlso25 = [0.935,0.8927,0.9372,0.925,0.9309]
# r2_11_nlso25 = [0.9239,0.9341,0.9342,0.9258,0.9277]
# r2_13_nlso25 = [0.9354,0.9329,0.9269,0.9334,0.9254]
# r2_15_nlso25 = [0.9247,0.9353,0.9355,0.9354,0.9237]
# r2_3_nlso50 = [0.9304,0.9322,0.9212,0.9301,0.9208]
# r2_5_nlso50 = [0.9298,0.9294,0.9303,0.9297,0.932]
# r2_7_nlso50 = [0.9291,0.9297,0.929,0.9304,0.9301]
# r2_9_nlso50 = [0.9271,0.9192,0.9295,0.9315,0.9284]
# r2_11_nlso50 = [0.932,0.9263,0.9298,0.9254,0.927]
# r2_13_nlso50 = [0.9313,0.9319,0.929,0.9291,0.93]
# r2_15_nlso50 = [0.9308,0.9307,0.9323,0.9337,0.9311]
# r2_3_nlso75 = [0.9187,0.9188,0.9151,0.9165,0.9151]
# r2_5_nlso75= [0.9217,0.9204,0.9193,0.921,0.9135]
# r2_7_nlso75 = [0.915,0.9165,0.9194,0.9164,0.9033]
# r2_9_nlso75 = [0.9154,0.9133,0.9139,0.9161,0.9187]
# r2_11_nlso75 = [0.9185,0.9178,0.9121,0.9118,0.9174]
# r2_13_nlso75 = [0.9148,0.9094,0.9232,0.9194,0.9251]
# r2_15_nlso75 = [0.9178,0.9136,0.9129,0.9177,0.9275]
# r2_3_nlso1 = [0.9015,0.9033,0.9012,0.9063,0.9044]
# r2_5_nlso1 = [0.9017,0.8994,0.8989,0.9061,0.8988]
# r2_7_nlso1 = [0.8998,0.8941,0.9014,0.9031,0.8856]
# r2_9_nlso1 = [0.9022,0.8967,0.902,0.8945,0.9019]
# r2_11_nlso1 = [0.9056,0.8976,0.8919,0.8898,0.9104]
# r2_13_nlso1 = [0.9025,0.9138,0.9021,0.907,0.9022]
# r2_15_nlso1 = [0.8988,0.8964,0.8952,0.8994,0.8932]

# outer21 woobs
r2_3 = [-0.0082,-0.0271,-0.0084,-0.0247,-0.013]
r2_5 = [0.0014,-0.0042,-0.0081,-0.0112,0.0052]
r2_7 = [0.0287,0.0062,0.0106,-0.0092,0.1047]
r2_9 = [0.0959,0.014,0.0042,0.0132,-0.003]
r2_11 = [0.1112,0.0245,0.014,0.1431,0.0581]
r2_13 = [0.1016,0.1606,0.1412,0.1705,0.0349]
r2_15 = [0.1062,0.1421,0.153,0.0921,0.1228]
r2_3_lso = [0.546,0.5683,0.5556,0.5589,0.5602]
r2_5_lso = [0.5579,0.5543,0.5165,0.5605,0.551]
r2_7_lso = [0.5593,0.5598,0.5568,0.6199,0.5666]
r2_9_lso = [0.6355,0.625,0.6185,0.5667,0.5952]
r2_11_lso = [0.6715,0.5845,0.6404,0.5678,0.68]
r2_13_lso = [0.5951,0.6453,0.6282,0.6089,0.563]
r2_15_lso = [0.5689,0.5812,0.6008,0.664,0.659]
r2_3_nlso = [0.6919,0.3093,0.6554,0.693,0.2282]
r2_5_nlso = [0.6872,0.6889,0.6846,0.4277,0.6843]
r2_7_nlso = [0.6897,0.6868,0.7004,0.6837,0.6875]
r2_9_nlso = [0.1069,0.281,-0.0809,0.2712,0.4525]
r2_11_nlso = [0.7748,0.4279,0.2442,0.7269,0.4765]
r2_13_nlso = [0.5631,0.365,0.4285,0.7788,0.7461]
r2_15_nlso = [0.7726,0.7384,0.5086,0.4967,0.781]
r2_3_nlso25 = [0.6421,0.6345,0.6298,0.6444,0.6161]
r2_5_nlso25 = [0.5731,0.6349,0.6395,0.6308,0.6373]
r2_7_nlso25 = [0.7253,0.6675,0.6654,0.6377,0.7041]
r2_9_nlso25 = [0.6546,0.747,0.7488,0.6658,0.6445]
r2_11_nlso25 = [0.7581,0.6567,0.6972,0.704,0.7715]
r2_13_nlso25 = [0.766,0.7713,0.7658,0.769,0.6743]
r2_15_nlso25 = [0.7836,0.7797,0.7701,0.7869,0.77]
r2_3_nlso50 = [0.6379,0.6678,0.6712,0.6594,0.6444]
r2_5_nlso50 = [0.6965,0.6707,0.6335,0.6816,0.6528]
r2_7_nlso50 = [0.7018,0.6962,0.7102,0.6496,0.6962]
r2_9_nlso50 = [0.6784,0.7371,0.713,0.7274,0.6941]
r2_11_nlso50 = [0.7649,0.7404,0.7712,0.7557,0.7547]
r2_13_nlso50 = [0.7546,0.7792,0.792,0.736,0.7949]
r2_15_nlso50 = [0.7707,0.7785,0.7817,0.7856,0.7882]
r2_3_nlso75 = [0.6189,0.6131,0.6182,0.6159,0.6172]
r2_5_nlso75= [0.6152,0.6161,0.6241,0.6135,0.6175]
r2_7_nlso75 = [0.6563,0.6546,0.6152,0.65,0.6258]
r2_9_nlso75 = [0.6459,0.6801,0.6376,0.6368,0.6801]
r2_11_nlso75 = [0.6552,0.7171,0.7286,0.6815,0.7093]
r2_13_nlso75 = [0.6292,0.7233,0.7144,0.7186,0.7601]
r2_15_nlso75 = [0.7137,0.7428,0.7272,0.718,0.7041]
r2_3_nlso1 = [0.5588,0.5558,0.5633,0.5589,0.5536]
r2_5_nlso1 = [0.5612,0.5552,0.5895,0.5583,0.5602]
r2_7_nlso1 = [0.5821,0.5569,0.5525,0.575,0.6281]
r2_9_nlso1 = [0.5855,0.5695,0.6024,0.5833,0.6906]
r2_11_nlso1 = [0.6687,0.6461,0.5892,0.5782,0.657]
r2_13_nlso1 = [0.645,0.6105,0.6745,0.6372,0.7]
r2_15_nlso1 = [0.6918,0.6473,0.6621,0.6804,0.6467]

r2_woobs = [r2_3, r2_5, r2_7, r2_9, r2_11, r2_13, r2_15]
r2_woobs = np.array(r2_woobs, dtype=float)
r2_lso = [r2_3_lso, r2_5_lso, r2_7_lso, r2_9_lso, r2_11_lso, r2_13_lso, r2_15_lso]
r2_lso = np.array(r2_lso, dtype=float)
r2_nlso = [r2_3_nlso, r2_5_nlso, r2_7_nlso, r2_9_nlso, r2_11_nlso, r2_13_nlso, r2_15_nlso]
r2_nlso = np.array(r2_nlso, dtype=float)
r2_nlso25 = [r2_3_nlso25, r2_5_nlso25, r2_7_nlso25, r2_9_nlso25, r2_11_nlso25, r2_13_nlso25, r2_15_nlso25]
r2_nlso25 = np.array(r2_nlso25, dtype=float)
r2_nlso50 = [r2_3_nlso50, r2_5_nlso50, r2_7_nlso50, r2_9_nlso50, r2_11_nlso50, r2_13_nlso50, r2_15_nlso50]
r2_nlso50 = np.array(r2_nlso50, dtype=float)
r2_nlso75 = [r2_3_nlso75, r2_5_nlso75, r2_7_nlso75, r2_9_nlso75, r2_11_nlso75, r2_13_nlso75, r2_15_nlso75]
r2_nlso75 = np.array(r2_nlso75, dtype=float)
r2_nlso1 = [r2_3_nlso1, r2_5_nlso1, r2_7_nlso1, r2_9_nlso1, r2_11_nlso1, r2_13_nlso1, r2_15_nlso1]
r2_nlso1 = np.array(r2_nlso1, dtype=float)

plt.figure(figsize=(6,4))
plt.plot(order, np.mean(r2_lso,axis=1).T)
plt.plot(order, np.mean(r2_nlso,axis=1).T)
plt.plot(order, np.mean(r2_nlso25,axis=1).T)
plt.plot(order, np.mean(r2_nlso50,axis=1).T)
plt.plot(order, np.mean(r2_nlso75,axis=1).T)
plt.plot(order, np.mean(r2_nlso1,axis=1).T)
plt.xlabel("Order")
plt.ylabel("Test R2 score")
plt.legend(["Linear Observer",
            "Nonlinear Obserber(trainable $\delta$)",
            "Nonlinear Obserber($\delta$=0.25)", 
            "Nonlinear Obserber($\delta$=0.5)",
            "Nonlinear Obserber($\delta$=0.75)", 
            "Nonlinear Obserber($\delta$=1)"], loc="lower right")
plt.grid(axis='y')
plt.savefig("../figs/outer21_line_nlso", dpi=300, bbox_inches='tight')
plt.show()

# %%
order = [3, 5, 7, 9, 11, 13, 15]
layer = [1, 2, 3, 4, 5]
# multi_layer = [[0.65614,0.66702,0.6908,0.71,0.75738,0.77134,0.78094], 
#               [0.6567,0.652666667,0.714666667,0.7468,0.7458,0.748833333,0.7297], 
#               [0.640733333,0.674366667,0.718166667,0.7267,0.7766,0.7749,0.782233333], 
#               [0.622433333,0.658333333,0.687266667,0.7409,0.768466667,0.7785,0.784166667],
#               [0.654466667,0.659166667,0.734,0.722533333,0.753233333,0.779933333,0.783933333]]
multi_layer = [[0.92694,0.93024,0.92966,0.92714,0.9281,0.93026,0.93172], 
              [0.930233333,0.927333333,0.9295,0.927433333,0.9303,0.930866667,0.926966667], 
              [0.927766667,0.9266,0.931,0.9288,0.9228,0.927633333,0.9315], 
              [0.923133333,0.929366667,0.916366667,0.9193,0.921366667,0.9274,0.930466667],
              [0.9243,0.915333333,0.9198,0.920566667,0.9242,0.925166667,0.935033333]]
plt.figure(figsize=(6,4))
plt.plot(order, multi_layer[0])
plt.plot(order, multi_layer[1])
plt.plot(order, multi_layer[2])
plt.plot(order, multi_layer[3])
plt.plot(order, multi_layer[4])

plt.legend(['Layer 1', 'Layer 2', 'Layer 3', 'Layer 4', 'Layer 5'])

plt.figure(figsize=(6,4))
plt.plot(layer, [np.mean(multi_layer[0][3:]),np.mean(multi_layer[1][3:]),np.mean(multi_layer[2][3:]),np.mean(multi_layer[3][3:]),np.mean(multi_layer[4][3:])])


plt.show()

# %%
label = [3, 5, 7, 9, 11, 13, 15]

# outer07 tanh
# r2_3_tanh = [0.0177,0.0171,0.0154,0.0167,0.0175]
# r2_5_tanh = [0.0218,0.2087,0.0197,0.0146,0.0269]
# r2_7_tanh = [0.0334,0.0285,0.0251,0.0256,0.0223]
# r2_9_tanh = [0.0634,0.0397,0.0368,0.0281,0.0242]
# r2_11_tanh = [0.2349,0.0545,0.2383,0.2249,0.2463]
# r2_13_tanh = [0.0378,0.2112,0.246,0.0303,0.0461]
# r2_15_tanh = [0.2487,0.2488,0.0325,0.2458,0.05]
# # outer07 relu
# r2_3_relu = [0.0174,0.03,0.0213,0.0158,0.0215]
# r2_5_relu = [0.0214,0.0181,0.0313,0.0253,0.0571]
# r2_7_relu = [0.0297,-0.1518,0.0326,0.0323,0.0254]
# r2_9_relu = [0.0293,0.2468,0.0313,0.2328,0.2204]
# r2_11_relu = [0.0356,0.248,0.2433,0.0819,-0.1417]
# r2_13_relu = [-0.1339,0.2398,0.0488,0.0349,0.2415]
# r2_15_relu = [-0.1482,0.2468,0.0346,0.2365,0.2414]
# # outer07 softplus
# r2_3_softplus = [0.0041,0.0089,0.0143,0.0112,0.0099]
# r2_5_softplus = [0.019,0.0169,0.0198,0.02,0.0126]
# r2_7_softplus = [0.2154,0.0506,0.0246,0.2186,0.0245]
# r2_9_softplus = [0.0314,0.0554,0.0288,0.0293,0.2096]
# r2_11_softplus = [0.2118,0.0315,0.0313,0.0316,0.2248]
# r2_13_softplus = [0.2253,0.0429,0.0418,0.2318,0.229]
# r2_15_softplus = [0.0359,0.2345,0.0328,0.2272,0.0375]

# # outer21 tanh
r2_3_tanh = [-0.0239,-0.022,-0.0149,-0.0227,-0.0163]
r2_5_tanh = [-0.0152,-0.027,-0.0177,0.0005,-0.0341]
r2_7_tanh = [0.0114,-0.0295,0.0481,-0.0011,-0.0104]
r2_9_tanh = [0.0247,0.0085,0.009,0.0862,-0.0057]
r2_11_tanh = [-0.0031,-0.0025,0.0134,0.0184,0.0029]
r2_13_tanh = [0.0897,-0.0101,0.0026,0.0065,0.0797]
r2_15_tanh = [0.0052,0.1132,0.0008,0.1336,0.0207]
# outer21 relu
r2_3_relu = [-0.0227,-0.0242,-0.0196,-0.0219,-0.0336]
r2_5_relu = [-0.0178,-0.0086,-0.0128,-0.0101,-0.0063]
r2_7_relu = [-0.0125,-0.0252,-0.0086,-0.0151,-0.0064]
r2_9_relu = [0.0071,0.0055,-0.0091,-0.0061,0.0076]
r2_11_relu = [0.0228,-0.0022,0.1448,0.0144,0.0101]
r2_13_relu = [0.0111,0.0567,0.0598,0.0016,0.1617]
r2_15_relu = [0.0107,-0.2003,0.0217,0.0169,-0.4106]
# outer21 softplus
r2_3_softplus = [-0.0517,-0.047,-0.0432,-0.0443,-0.0439]
r2_5_softplus = [-0.0287,-0.0007,0.0056,-0.0229,-0.0087]
r2_7_softplus = [-0.0171,-0.0213,-0.0171,-0.019,-0.0052]
r2_9_softplus = [0.0043,-0.0057,-0.0026,0.0984,-0.0095]
r2_11_softplus = [-0.0085,0.106,-0.0014,-0.0087,0.1411]
r2_13_softplus = [0.1044,0.0035,0.0654,-0.0048,0.031]
r2_15_softplus = [0.1005,0.1166,0.0125,0.1275,0.1063]


# outer07 woobs
# r2_3 = [0.0186,0.032,0.0166,0.023,0.018]
# r2_5 = [0.025,0.025,0.028,0.025,0.026]
# r2_7 = [0.032,0.028,0.031,0.028,0.029]
# r2_9 = [0.034,0.241,0.033,0.028,0.031]
# r2_11 = [0.0797,0.2474,0.2297,0.2371,0.2464]
# r2_13 = [0.2414,0.2375,0.0366,0.2365,0.0415]
# r2_15 = [0.2334,0.2488,0.254,0.2364,0.2147]
# outer21 woobs
r2_3 = [-0.0082,-0.0271,-0.0084,-0.0247,-0.013]
r2_5 = [0.0014,-0.0042,-0.0081,-0.0112,0.0052]
r2_7 = [0.0287,0.0062,0.0106,-0.0092,0.1047]
r2_9 = [0.0959,0.014,0.0042,0.0132,-0.003]
r2_11 = [0.1112,0.0245,0.014,0.1431,0.0581]
r2_13 = [0.1016,0.1606,0.1412,0.1705,0.0349]
r2_15 = [0.1062,0.1421,0.153,0.0921,0.1228]

outer_woobs_mean = [np.mean(r2_3), np.mean(r2_5), np.mean(r2_7), np.mean(r2_9), np.mean(r2_11), np.mean(r2_13), np.mean(r2_15)]
outer_tanh_mean = [np.mean(r2_3_tanh), np.mean(r2_5_tanh), np.mean(r2_7_tanh), np.mean(r2_9_tanh), np.mean(r2_11_tanh), np.mean(r2_13_tanh), np.mean(r2_15_tanh)]
outer_relu_mean = [np.mean(r2_3_relu), np.mean(r2_5_relu), np.mean(r2_7_relu), np.mean(r2_9_relu), np.mean(r2_11_relu), np.mean(r2_13_relu), np.mean(r2_15_relu)]
outer_softplus_mean = [np.mean(r2_3_softplus), np.mean(r2_5_softplus), np.mean(r2_7_softplus), np.mean(r2_9_softplus), np.mean(r2_11_softplus), np.mean(r2_13_softplus), np.mean(r2_15_softplus)]

plt.figure(figsize=(6,4))
plt.plot(outer_woobs_mean)
plt.plot(outer_tanh_mean)
plt.plot(outer_relu_mean)
plt.plot(outer_softplus_mean)
plt.grid(axis='y')
plt.legend(['Baseline', 'Tanh activation', 'ReLU activation', 'SoftPlus activation'])
plt.ylabel('Average R2 score')
plt.xlabel('Order of model')
plt.savefig("../figs/outer21_compare_active", dpi=300, bbox_inches='tight')

# %%
label = [3, 5, 7, 9, 11, 13, 15]

# outer07 woobs
r2_3 = [0.0186,0.032,0.0166,0.023,0.018]
r2_5 = [0.025,0.025,0.028,0.025,0.026]
r2_7 = [0.032,0.028,0.031,0.028,0.029]
r2_9 = [0.034,0.241,0.033,0.028,0.031]
r2_11 = [0.0797,0.2474,0.2297,0.2371,0.2464]
r2_13 = [0.2414,0.2375,0.0366,0.2365,0.0415]
r2_15 = [0.2334,0.2488,0.254,0.2364,0.2147]
# outer21 woobs
# r2_3 = [-0.0082,-0.0271,-0.0084,-0.0247,-0.013]
# r2_5 = [0.0014,-0.0042,-0.0081,-0.0112,0.0052]
# r2_7 = [0.0287,0.0062,0.0106,-0.0092,0.1047]
# r2_9 = [0.0959,0.014,0.0042,0.0132,-0.003]
# r2_11 = [0.1112,0.0245,0.014,0.1431,0.0581]
# r2_13 = [0.1016,0.1606,0.1412,0.1705,0.0349]
# r2_15 = [0.1062,0.1421,0.153,0.0921,0.1228]

plt.figure(figsize=(6,4))
plt.boxplot([r2_3, r2_5, r2_7, r2_9, r2_11, r2_13, r2_15], labels=label, showmeans=True)
plt.ylabel("R2 score")
plt.xlabel("Order of model")
plt.savefig("../figs/outer07_box_woobs", dpi=300, bbox_inches='tight')
